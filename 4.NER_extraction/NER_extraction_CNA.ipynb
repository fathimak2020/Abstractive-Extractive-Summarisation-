# %%
import pandas as pd

import re

import nltk
from nltk.tokenize import word_tokenize

import spacy
from spacy.lang.en import English
nlp = spacy.load("en_core_web_sm")

# %% [markdown]
# ## Definitions

# %%
# extracting words with labels: person, gpe, location and organisation
def extract_ne_from_tree ( tree ):
    result = []
    for s in tree.subtrees():
        label = s.label()
        if (label == 'PERSON' or label == 'GPE' or label == 'LOCATION' or label == 'ORGANIZATION'):
            leaves = s.leaves()
            ne = ''
            for l in leaves:
                ne = ne + ' ' + l[0]
            result.append((label, ne[1:]))
    return result

# %%
#tokenise, pos tagging, extracting words with labels above & place them into a list
def ner_info_extraction(content ,content_list):
    for x in content:
        res_sents = nltk.sent_tokenize(x)
        res_tokens = [word_tokenize(sents) for sents in res_sents]
        tagged_res = [nltk.pos_tag(tokens) for tokens in res_tokens]
        res_tree = [nltk.ne_chunk(elem) for elem in tagged_res]
        res_list = [extract_ne_from_tree(tree) for tree in res_tree]
        content_list+=[(res_list)]

# %%
# Since cnn is present at the start of all articles, it creates noise in the entities extracted
def ner_sorting(content ,location, gpe, person, org):
    for row in content:
        check_location = []
        check_gpe = []
        check_person = []
        check_org = []
        for sent in row:
            if len(sent)!=0:
                for tup in sent:
                    if tup[1] != 'CNN':
                        if tup[0] == "LOCATION":
                            if tup[1] not in check_location:
                                check_location.append(tup[1])
                        if tup[0] == "GPE":
                            if tup[1] not in check_gpe:
                                check_gpe.append(tup[1])
                        if tup[0] == "PERSON":
                            if tup[1] not in check_person:
                                check_person.append(tup[1])
                        if tup[0] == "ORGANIZATION":
                            if tup[1] not in check_org:
                                check_org.append(tup[1])
        location.append(check_location)
        gpe.append(check_gpe)
        person.append(check_person)
        org.append(check_org)

# %%
# Extraction of entities using spaCy
def spacy_ner(content):
    nlist = []
    for x in content:
        cont_doc = nlp(x)
        temp = []
        for ent in cont_doc.ents:
            if ent.label_=="ORG" or ent.label_=="PERSON" or ent.label_=="GPE" or ent.label_=="LOC":
                temp.append([ent.text, ent.label_])
        nlist.append(temp)
    return nlist

# %%
# Since cnn is present at the start of all articles, it creates noise in the entities extracted
def spacy_sorting(content):
    org = []
    gpe = []
    person = []
    location = []
    for row in content:
        check_org = []
        check_gpe = []
        check_person = []
        check_loc = []
        if len(row)!=0:
            for tup in row:
                if tup[0]!= "CNN":
                    if tup[1] == "ORG":
                        if tup[0] not in check_org:
                            check_org.append(tup[0])
                    if tup[1] == "GPE":
                        if tup[0] not in check_gpe:
                            check_gpe.append(tup[0])
                    if tup[1] == "PERSON":
                        if tup[0] not in check_person:
                            check_person.append(tup[0])
                    if tup[1] == "LOC":
                        if tup[0] not in check_loc:
                            check_loc.append(tup[0])
        org.append(check_org)
        gpe.append(check_gpe)
        person.append(check_person)
        location.append(check_loc)
    return [org, gpe, person, location]

# %% [markdown]
# ## cnn news

# %%
import glob
import os

path = r'../2.text_preprocessing/cna/cna_FINAL.csv' # use your path

#Importing in the news articles
cna = pd.read_csv(path)
cna = cna.loc[:,['url','text']]
print(cna.shape)
cna
# Out:
# (139, 2)
#                                                    url  \
# 0    https://www.channelnewsasia.com/sport/steely-m...
# 1    https://www.channelnewsasia.com/sport/choupo-m...
# 2    https://www.channelnewsasia.com/sport/chelsea-...
# 3    https://www.channelnewsasia.com/sport/nothing-...
# 4    https://www.channelnewsasia.com/sport/contes-c...
# ..                                                 ...
# 134  https://www.channelnewsasia.com/sport/fa-cup-q...
# 135  https://www.channelnewsasia.com/sport/man-unit...
# 136  https://www.channelnewsasia.com/sport/formula-...
# 137  https://www.channelnewsasia.com/sport/prop-hao...
# 138  https://www.channelnewsasia.com/sport/police-c...
#
#                                                   text
# 0    LONDON :Seven-time winners AC Milan reached th...
# 1    MUNICH :Bayern Munich forward Eric-Maxim Choup...
# 2    LONDON: Chelsea's Guro Reiten scored from the ...
# 3    LONDON: AC Milan can dare to dream about going...
# 4    LONDON: Antonio Conte's dismal record in the C...
# ..                                                 ...
# 134  LONDON : FA Cup quarter-final draw made on Wed...
# 135  MANCHESTER, England :Manchester United fought ...
# 136  Statistics for Sunday's season-opening Bahrain...
# 137  Prop Mohamed Haouas will miss France's remaini...
# 138  On the cusp of the biggest moment of his life,...
#
# [139 rows x 2 columns]

# %% [markdown]
# NLTK extraction

# %%
# Extracting using NLTK with the help of defined function above
cna_content = []

ner_info_extraction(cna['text'],cna_content)
    
print(cna_content)
# Out:
# [[[('ORGANIZATION', 'AC Milan'), ('ORGANIZATION', 'Champions League'), ('ORGANIZATION', 'Tottenham Hotspur')], [('ORGANIZATION', 'Italians'), ('ORGANIZATION', 'San Siro'), ('GPE', 'Tottenham')], [('PERSON', 'Tottenham'), ('PERSON', 'Antonio Conte'), ('PERSON', 'Cristian Romero')], [('PERSON', 'Milan')], [('PERSON', 'Stefano Pioli'), ('PERSON', 'Milan'), ('PERSON', 'Tottenham'), ('ORGANIZATION', 'Sheffield United'), ('PERSON', 'Wolverhampton Wanderers')], [('PERSON', 'Milan'), ('GPE', 'European'), ('PERSON', 'Pioli')], [], [], [('PERSON', 'Pioli')], [], [('PERSON', 'Tottenham')], [], [('GPE', 'Tottenham'), ('PERSON', 'Harry Kane'), ('PERSON', 'Son Heung-min'), ('PERSON', 'Dejan Kulusevski'), ('PERSON', 'Milan'), ('PERSON', 'Junior Messias')], [('ORGANIZATION', 'Italians'), ('PERSON', 'Brahim Diaz'), ('PERSON', 'Fraser Forster')], [('PERSON', 'Tottenham'), ('PERSON', 'Milan'), ('PERSON', 'Mike Maignan')], [('PERSON', 'Tottenham'), ('PERSON', 'Rafael Leao')], [('PERSON', 'Kane'), ('PERSON', 'Tottenham'), ('PERSON', 'Richarlison'), ('PERSON', 'Emerson')], [('PERSON', 'Conte'), ('ORGANIZATION', 'Kulusevski'), ('PERSON', 'Davinson Sanchez')], [('PERSON', 'Kane'), ('PERSON', 'Maignan'), ('PERSON', 'Milan'), ('PERSON', 'Divock Origi')]], [[('GPE', 'MUNICH'), ('PERSON', 'Bayern Munich'), ('PERSON', 'Serge Gnabry'), ('GPE', 'Germans'), ('PERSON', 'Paris St Germain'), ('ORGANIZATION', 'Champions League')], [('ORGANIZATION', 'PSG'), ('PERSON', 'Leon Goretzka'), ('PERSON', 'Gnabry'), ('GPE', 'Paris')], [('GPE', 'Germans'), ('ORGANIZATION', 'PSG'), ('PERSON', 'Lionel Messi'), ('PERSON', 'Kylian Mbappe')], [('GPE', 'Bayern'), ('PERSON', 'Julian Nagelsmann')], [], [], [], [], [('ORGANIZATION', 'PSG'), ('GPE', 'Europe')], [('PERSON', 'Neymar'), ('GPE', 'French'), ('PERSON', 'Mbappe'), ('GPE', 'Messi')], [('GPE', 'Bayern'), ('PERSON', 'Jamal Musiala'), ('PERSON', 'Gianluigi Donnarumma')], [('ORGANIZATION', 'PSG'), ('PERSON', 'Marquinhos'), ('LOCATION', 'Bayern'), ('PERSON', 'Yann Sommer')], [('GPE', 'Vitinha'), ('PERSON', 'Matthijs')], [('GPE', 'Dutch'), ('ORGANIZATION', 'VfB Stuttgart')], [('PERSON', 'Mbappe')], [('ORGANIZATION', 'PSG'), ('PERSON', 'Sergio Ramos'), ('ORGANIZATION', 'Sommer'), ('ORGANIZATION', 'Spaniard'), ('PERSON', 'Gnabry'), ('GPE', 'Bayern')], [('ORGANIZATION', 'PSG'), ('PERSON', 'Christophe Galtier')], [], [], [], []], [[('PERSON', 'Chelsea'), ('PERSON', 'Guro Reiten'), ('PERSON', 'Johanna Rytting Kaneryd'), ('GPE', 'Brighton'), ('PERSON', 'Hove Albion'), ('ORGANIZATION', 'Super League'), ('PERSON', 'Manchester United')], [('GPE', 'United'), ('GPE', 'Chelsea')], [('GPE', 'Norway'), ('PERSON', 'Reiten'), ('PERSON', 'Sam Kerr'), ('ORGANIZATION', 'Jess Carter')], [('PERSON', 'Kerr'), ('PERSON', 'Reiten'), ('PERSON', 'Kaneryd'), ('ORGANIZATION', 'Swede'), ('GPE', 'Blues')], [('PERSON', 'Brighton'), ('PERSON', 'Danielle Carter'), ('PERSON', 'Leicester City')], [('GPE', 'Chelsea'), ('GPE', 'Women'), ('PERSON', 'Liverpool'), ('PERSON', 'Stina Blackstenius'), ('PERSON', 'Caitlin Foord')]], [[('PERSON', 'Milan'), ('ORGANIZATION', 'Champions League'), ('PERSON', 'Stefano Pioli'), ('PERSON', 'Tottenham Hotspur')], [('PERSON', 'Milan'), ('GPE', 'London')], [('PERSON', 'Pioli')], [('GPE', 'Europe'), ('GPE', 'European')], [], [('GPE', 'Milan'), ('GPE', 'Serie'), ('ORGANIZATION', 'AS Roma'), ('PERSON', 'Champions League')], [('ORGANIZATION', 'Champions League'), ('PERSON', 'Milan')], [('GPE', 'Serie'), ('PERSON', 'Pioli')], [('GPE', 'Milan'), ('PERSON', 'Chelsea'), ('PERSON', 'Bayern Munich'), ('PERSON', 'Benfica')], [('PERSON', 'Tottenham')], [], [('PERSON', 'Serie A')], []], [[('PERSON', 'Antonio Conte'), ('ORGANIZATION', 'Champions League'), ('ORGANIZATION', 'Tottenham Hotspur'), ('ORGANIZATION', 'AC Milan')], [('GPE', 'Tottenham')], [('PERSON', 'Conte'), ('GPE', 'London')], [('PERSON', 'Juventus'), ('ORGANIZATION', 'Inter Milan'), ('PERSON', 'Chelsea'), ('GPE', 'Tottenham'), ('GPE', 'Italian'), ('ORGANIZATION', 'Champions League')],  ...

# %%
#sort words according to labelled entities
location_with_brac = []
gpe_with_brac = []
person_with_brac = []
org_with_brac = []

ner_sorting(cna_content, location_with_brac, gpe_with_brac, person_with_brac, org_with_brac)

print(location_with_brac)
print()

print(gpe_with_brac)
print()

print(person_with_brac)
print()

print(org_with_brac)
# Out:
# [[], ['Bayern'], [], [], [], [], [], ['Northern Irishman'], [], ['Southern California'], [], [], [], [], [], ['East Brabant'], [], [], [], [], [], [], [], [], [], [], [], [], [], [], ['West Ham United'], [], ['South Africa', 'Caribbean'], [], [], [], ['West'], [], [], [], [], [], [], [], [], ['West', 'West Indies'], [], [], [], [], [], [], [], [], ['South'], [], [], [], [], [], ['Southeast'], ['South Korean'], [], [], [], [], ['West Ham United'], [], [], ['West Germany', 'West German'], [], [], [], [], [], [], [], ['Sebastian Munoz'], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], ['West Ham United'], [], ['South Africa', 'Caribbean'], [], [], [], [], ['West Ham United', 'West Bromwich'], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], ['West Germany', 'West German'], ['West'], [], ['Western Force'], [], [], [], [], [], [], ['West Ham'], [], [], []]
#
# [['Tottenham', 'European'], ['MUNICH', 'Germans', 'Paris', 'Bayern', 'Europe', 'French', 'Messi', 'Vitinha', 'Dutch'], ['Brighton', 'United', 'Chelsea', 'Norway', 'Blues', 'Women'], ['London', 'Europe', 'European', 'Milan', 'Serie'], ['Tottenham', 'London', 'Italian', 'Italy'], ['MUNICH', 'Germany', 'Bayern', 'Europe', 'France', 'European', 'Galtier'], ['Arsenal', 'Jesus', 'July', 'European', 'Portugal'], ['Rahm', 'Ponte', 'Florida', 'Fame', 'US', 'British', 'Australian'], ['Florida', 'New York'], ['INDIAN WELLS', 'Calif.', 'Indian', 'Doha'], ['Canada', 'Edmonton', 'Hamilton', 'Alberta', 'Calgary', 'Australia', 'Durban', 'South'], ['INDIAN WELLS', 'Ca', 'Indian', 'Florida', 'French', 'Norwegian', 'Canada', 'U.S.', 'Fritz', 'American'], ['Juventus', 'Freiburg', 'Torino', 'Serie', 'European', 'Turin', 'Germany', 'Europe'], ['Briton', 'Hamilton', 'Team', 'Bahrain', 'Austrian'], ['Chelsea', 'Germany', 'Leupolz', 'Australia', 'New Zealand'], ['Eindhoven', 'Serbian', 'Dutch', 'European'], ['Bayern', 'European', 'League', 'German'], ['England', 'Britain', 'Foxes', 'Barcelona', 'Japanese', 'English', 'English Football', 'Fame', 'British', 'Midway'], ['Amid', 'France', 'French', 'Fellow', 'Australia', 'Group', 'Panama', 'Canada', 'Spain'], ['England', 'Women', 'Haiti', 'Panama', 'Portugal', 'Ireland', 'Jul', 'Australia', 'New Zealand', 'Britain', 'PE', 'Canada', 'Allies', 'Sebastian'], ['BRUSSELS', 'Belgian', 'Parker', 'Bournemouth', 'Briton'], ['Dubai', 'Djokovic'], ['United', 'Dutch', 'Portuguese', 'Barcelona', 'August', 'Newcastle', 'Weghorst'], ['Newcastle', 'Saudi', 'United', 'English'], ['South Korea', 'Germany', 'United States', 'Canada', 'Mexico', 'Korean', 'Asian', 'Colombia', 'German'], ['British', 'Chelsea', 'Spurs'], ['PARIS', 'Mbappe', 'Argentine', 'France', 'Argentina', 'Marseille', 'Nice', 'French', 'Messi'], ['Spain', 'Almeria', 'Barca', 'Malian', 'La', 'Europe', 'Barcelona'], ['BOLOGNA', 'Italy', 'Bologna', 'Inzaghi', 'Porto', 'Soriano', 'Romelu'], ['Doha', 'Asian', 'Japan', 'Saudi Arabia', 'Urawa', 'Nigerian', 'Brazilian', 'Marega', 'Porto', 'Zakaria'], ['United', 'Rashford'], ['Bristol City', 'English', 'Bournemouth'], ['West', 'Zimbabwe', 'Australia', 'South Africa', 'Brathwaite', 'Discipline'], ['U.S.', 'Bahrain', 'Dutch', 'Sauber', 'Australian', 'Alpine', 'United States', 'German', 'Hamilton', 'Alonso', 'America', 'Netflix'], ['Bahrain', 'Abu Dhabi', 'U.S.', 'China', 'April', 'France', 'Qatar', 'Azerbaijan', 'Belgium', 'Brazil', 'Calendar', 'Sakhir', 'Saudi Arabia', 'Jeddah', 'Australia', 'Spain', 'Barcelona', 'Canada', 'Austria', 'Britain', 'Hungary', 'Netherlands', 'Italy', 'Singapore', 'Japan', 'Suzuka', 'United States', 'Austin', 'Mexico'], ['PARIS', 'French', 'Graet', 'France', 'Diacre', 'Fellow', 'Norway', 'England', 'Germany', 'Women', 'Australia', 'New Zealand'], ['South', 'West', 'Australia', 'England', 'Pretoria', 'South Africa'], ['Dubai', 'Murray', 'U.S.', 'Texas'], ['New Zealand', 'England', 'Taylor'], ['Spain'], ['Australia', 'India', 'Indore', 'Cummins', 'Indian', 'New Delhi'], ['Antalyaspor', 'Turkey', 'Ghana'], ['MADRID', 'Spanish', 'Almeria', 'LaLiga', 'Barcelona', 'Barca', 'Real', 'Madrid', 'Kessie', 'Osasuna'], ['Serbian', 'Adelaide', 'Australian', 'Dubai', 'French', 'Zverev', 'Russian'], ['MANAMA', 'Bahrain', 'Australian', 'Melbourne', 'Piastri'], ['South Africa', 'Bavuma', 'England', 'Australia', 'Pakistan', 'South', 'African'], ['MANAMA', 'Bahrain', 'Saudi Arabia', 'Hamilton', 'Briton'], ['MANAMA', 'Bahrain', 'Button', 'Dutch'], ['MADRID', 'Europe', 'Barcelona', 'Turkish', 'Club', 'Paris'], ['England', 'Brook', 'Florida'], ['U.S.', 'Agency', 'Olympian', 'Nash'], ['LONDON', 'Italy', 'Germany', 'Italian', 'New York'], ['LONDON', 'English', 'London', 'England', 'European', 'Europe', 'January'], ['England', 'Groups'], ['Rosario', 'Argentina', 'Javkin', 'Television', 'American', 'Qatar', 'Santiago', 'Curacao'], ['Argentina', 'Santiago', 'France', 'Qatar'], ['England', 'Saudi', 'Middle East', 'U.S ...
#
# [['Tottenham', 'Antonio Conte', 'Cristian Romero', 'Milan', 'Stefano Pioli', 'Wolverhampton Wanderers', 'Pioli', 'Harry Kane', 'Son Heung-min', 'Dejan Kulusevski', 'Junior Messias', 'Brahim Diaz', 'Fraser Forster', 'Mike Maignan', 'Rafael Leao', 'Kane', 'Richarlison', 'Emerson', 'Conte', 'Davinson Sanchez', 'Maignan', 'Divock Origi'], ['Bayern Munich', 'Serge Gnabry', 'Paris St Germain', 'Leon Goretzka', 'Gnabry', 'Lionel Messi', 'Kylian Mbappe', 'Julian Nagelsmann', 'Neymar', 'Mbappe', 'Jamal Musiala', 'Gianluigi Donnarumma', 'Marquinhos', 'Yann Sommer', 'Matthijs', 'Sergio Ramos', 'Christophe Galtier'], ['Chelsea', 'Guro Reiten', 'Johanna Rytting Kaneryd', 'Hove Albion', 'Manchester United', 'Reiten', 'Sam Kerr', 'Kerr', 'Kaneryd', 'Brighton', 'Danielle Carter', 'Leicester City', 'Liverpool', 'Stina Blackstenius', 'Caitlin Foord'], ['Milan', 'Stefano Pioli', 'Tottenham Hotspur', 'Pioli', 'Champions League', 'Chelsea', 'Bayern Munich', 'Benfica', 'Tottenham', 'Serie A'], ['Antonio Conte', 'Conte', 'Juventus', 'Chelsea', 'Tottenham', 'Wolverhampton Wanderers', 'Milan'], ['Paris St Germain', 'Bayern Munich', 'Coach', 'Christophe Galtier', 'Kylian Mbappe', 'Lionel Messi', 'Galtier', 'Mbappe', 'Messi', 'Bayern', 'Serge Gnabry'], ['Gabriel Jesus', 'Mikel Arteta', 'Manchester City', 'Brazil', 'Arteta', 'Fabio Vieira', 'Kieran', 'Eddie Nketiah', 'Leandro Trossard', 'Ruben Amorim', 'Tottenham'], ['Jon', 'Rahm', 'Cameron Smith', 'Johnny Miller', 'March', 'Rory McIlroy', 'Scheffler', 'Max', 'Homa', 'Smith', 'Anirban Lahiri', 'Dustin Johnson', 'Paul Casey', 'Harold Varner III'], ['Tiger', 'Woods', 'Erica Herman', 'Martin County', 'Herman', 'Joe Biden', 'Benjamin Hodas', 'Hodas'], ['Iga Swiatek', 'Dubai'], ['Alberta', 'Calgary', 'Hamilton', 'Claire Carver-Dias', 'Roger Jackson', 'Jackson', 'Jyoti Gondek', 'Gondek', 'Victoria', 'Birmingham', 'Africa'], ['Break Point', 'Casper Ruud', 'Felix Auger Aliassime', 'Taylor Fritz', 'Ruud', 'Netflix', 'Auger Aliassime', 'Maria'], ['Massimiliano Allegri', 'Paul Pogba', 'Europa League', 'Pogba', 'Allegri'], ['Lewis Hamilton', 'Mercedes', 'Bahrain Grand Prix', 'Hamilton', 'Live', 'Chequered Flag', 'Formula One', 'Toto Wolff', 'Red Bull', 'Red', 'Max Verstappen', 'Mexican Sergio Perez', 'Aston', 'Martin'], ['Chelsea', 'Melanie Leupolz', 'Leupolz', 'Emma Hayes', 'Sky Sports', 'Emma', 'Hayes', 'Women', 'Melanie'], ['Sevilla', 'Marko Dmitrovic', 'Dmitrovic'], ['Paris St Germain'], ['Gary', 'Lineker', 'Match', 'Brexit', 'Suella Braverman', 'Braverman', 'Leicester City', 'Everton', 'Tottenham Hotspur', 'Nagoya Grampus Eight', 'Bobby Charlton', 'Wayne', 'Harry Kane', 'Leicester'], ['Corinne Diacre', 'Wendie Renard', 'Renard', 'Diacre', 'Jamaica', 'Brazil', 'Canada Soccer'], ['Fatma Samoura', 'Morocco', 'Vietnam', 'Zambia', 'Samoura', 'Lionesses', 'Schools', 'Hayley', 'Tennis Federation', 'David Haggerty', 'Haggerty', 'Advantage All Male Allies', 'Coe', 'World Athletics'], ['Club Brugge', 'Scott Parker', 'Benfica', 'Brugge', 'Fulham', 'Carl Hoefkens', 'League'], ['Novak', 'Djokovic', 'Rafa Nadal', 'Serb', 'Steffi Graf', 'Graf', 'Czech Tomas Machac'], ['Erik', 'Marcus Rashford', 'Casemiro', 'Lisandro Martinez', 'Raphael Varane', 'Antony', 'Ten Hag'], ['United', 'Casemiro', 'Sven Botman', 'Eddie Howe', 'Erik', 'Hag', 'Jose Mourinho', 'Bruno Fernandes', 'Brazilian Casemiro', 'Luke Shaw', 'Loris Karius', 'Marcus Rashford', 'Karius', 'Dutchman Ten Hag'], ['Juergen', 'Klinsmann', 'Paulo Bento', 'Brazil', 'Bayern Munich'], ['Tottenham Hotspur', 'Chelsea', 'Oliver Skipp', 'Harry Kane', 'Spurs', 'Graham Potter', 'Skipp', 'Enzo Fernandez', 'Kepa Arrizabalaga', 'Kane', 'Son Heung-min', 'Eric Dier', 'Potter'], ['Lionel Messi', 'Kylian Mbappe', 'Paris St Germain', 'Marseille', 'Messi', 'Neymar', 'Mbappe', 'Edinson Cavani', 'Sergio Ramos', 'Igor Tudor', 'Monaco', 'Khephren Thuram', 'Lille', 'Presnel Kimpembe', 'Matteo', 'Guendouzi', 'Pau Lopez', 'Lopez', 'Marquinhos', 'Gianluigi', 'Donnarumma', 'Nuno Tavares', 'Nantes', 'B ...
#
# [['AC Milan', 'Champions League', 'Tottenham Hotspur', 'Italians', 'San Siro', 'Sheffield United', 'Kulusevski'], ['Champions League', 'PSG', 'VfB Stuttgart', 'Sommer', 'Spaniard'], ['Super League', 'Jess Carter', 'Swede'], ['Champions League', 'AS Roma'], ['Champions League', 'Tottenham Hotspur', 'AC Milan', 'Inter Milan', 'Conte', 'Amazon', 'Europa Conference League', 'Sheffield United'], ['Champions League', 'PSG'], ['Arsenal', 'US', 'Europa League', 'Tierney'], ['Players', 'LIV Golf', 'TPC Sawgrass', 'Spaniard', 'Bay Hill', 'PGA Tour', 'US', 'PGA', 'Year Scottie Scheffler', 'McIlroy', 'TRIUMPH', 'Phoenix Open', 'Smith', 'TPC'], ['Woods', 'Speak Out Act', 'NDAs', 'US Open'], ['Pole', 'Dubai Tennis'], ['CSC', 'Alberta', 'Commonwealth Sport Canada', 'CEO', 'Commonwealth'], ['Netflix', 'Publix', 'Formula'], ['Juventus', 'Manchester United'], ['Mercedes', 'BBC', 'Bull', 'Fernando Alonso'], ['English Women', 'Super League', 'Football Association', 'German', 'ACL'], ['PSV', 'Europa League', 'District Court', 'Philips', 'UEFA'], ['Munich', 'UEFA', 'Parc'], ['BBC', 'Channel', 'Nazi Germany', 'England', 'PROLIFIC', 'Rooney'], ['RMC Sport', 'Kadidiatou Diani', 'Euro', 'Football Federation', 'FFF', 'New Zealand'], ['FIFA', 'International Women', 'Wickenheiser', 'International', 'ITF', 'United Nations'], ['Champions League', 'Englishman', 'Club Brugge', 'Benfica'], ['ATP Tour', 'Adelaide'], ['League', 'Newcastle United', 'Wembley', 'Old Trafford', 'Ajax Amsterdam', 'American Glazer', 'Europa League', 'Brentford'], ['Newcastle United', 'League', 'Manchester United', 'Europa League', 'VAR', 'Newcastle', 'Tyneside'], ['Korea Football Association', 'KFA', 'Gus Hiddink', 'US', 'CONCACAF', 'CONCACAF Coach'], ['Blues', 'Newcastle United'], ['PSG', 'Montpellier', 'Argentine', 'Parc'], ['LaLiga', 'Real', 'Atletico Madrid', 'Europa League', 'Movistar Plus', 'Real Madrid'], ['Bologna', 'AC Milan', 'AS Roma', 'VAR', 'Lukaku', 'DAZN', 'Inter', 'Nerazzurri', 'AC'], ['Manchester United', 'Mali', 'VAR'], ['Newcastle United', 'Old Trafford', 'Europa League'], ['Ashton Gate', 'League', 'City', 'Arsenal'], ['Indies', 'Centurion Park'], ['Bull', 'Max Verstappen', 'Mercedes', 'TRIPLE', 'MAX Verstappen', 'NEW', 'BOSSES Four', 'Ferrari', 'McLaren', 'Frenchman', 'FACES', 'Red', 'Williams', 'OLD', 'FACES Nico Hulkenberg', 'Haas', 'Fernando Alonso', 'Hamilton', 'One', 'TEAMS Andretti', 'MERCEDES', 'DEAL Hamilton', 'FIA', 'RICCIARDO', 'Red Bull'], ['Vegas', 'Melbourne', 'Baku', 'Imola', 'Montreal', 'Spielberg', 'Zandvoort', 'Interlagos'], ['FFF', 'Sports', 'Kadidiatou Diani', 'RMC Sport', 'Euro', 'European'], ['Africa', 'Centurion Park'], ['Dubai Tennis', 'ATP', 'Qatar Open', 'Medvedev', 'Austin Open'], ['Wellington'], ['Isle', 'Twenty20', 'Cricbuzz', 'T20s', 'Adelaide Strikers'], ['Mitchell'], ['Turkish Super Lig', 'Vodafone Park'], ['Real Madrid', 'Real', 'Europa League', 'TVE', 'VAR'], ['Dubai Tennis', 'Roland Garros', 'ATP', 'Zandschulp'], ['Formula One', 'Sakhir', 'FIA', 'Fernando Alonso', 'Fernando', 'McLaren', 'AlphaTauri', 'Nyck', 'Monza', 'Williams', 'US'], ['Centurion', 'Bangladesh'], ['Mercedes', 'Sakhir', 'Formula One', 'Netflix'], ['Mercedes', 'Daily Telegraph', 'Sakhir', 'Bull'], ['US', 'Goldman Sachs', 'Kroll Bond', 'KBRA', 'Nou Camp', 'BBB', 'Sachs', 'Nou', 'VIP', 'LaLiga', 'FFP', 'Lionel Messi'], ['MLB', 'Cardinals', 'MLB Europe', 'Chicago Cubs', 'London Stadium'], ['Czech', 'USADA', 'WADA', 'International Cycling Union'], ['AC', 'RedBird Capital', 'Financial Times Business', 'Football Summit', 'Goldman Sachs', 'Bundesliga', 'English', 'RedBird', 'AC Milan', 'Yankees'], ['UEFA', 'Financial Times Business', 'Football Summit', 'UK Home', 'GBE', 'Football Association', 'BIGGEST', 'SPENDERS Chelsea', 'American Todd Boehly', 'Bundesliga', 'LaLiga'], ['RFU', 'RFU Council'], ['Lionel Messi', 'Roccuzzos', 'Roccuzzo', 'Rosario', 'Angelica Medina'], ['Lionel Scaloni', 'Monumental', 'Madre', 'Argentine', 'AFA'], ['Newcastle United', 'Public Investment Fund ...

# %%
# add into dataframe
cna['location_with_brac'] = location_with_brac
cna['gpe_with_brac'] = gpe_with_brac
cna['person_with_brac'] = person_with_brac
cna['org_with_brac'] = org_with_brac

cna['nltk_location']=cna['location_with_brac'].apply(lambda x: ','.join(map(str, x)))
cna['nltk_gpe'] = cna['gpe_with_brac'].apply(lambda x: ', '.join(map(str, x)))
cna['nltk_person'] = cna['person_with_brac'].apply(lambda x: ', '.join(map(str, x)))
cna['nltk_org'] = cna['org_with_brac'].apply(lambda x: ', '.join(map(str, x)))

cna = cna.drop(columns=['location_with_brac','gpe_with_brac','person_with_brac', 'org_with_brac'],axis = 1)

cna.head()
# Out:
#                                                  url  \
# 0  https://www.channelnewsasia.com/sport/steely-m...
# 1  https://www.channelnewsasia.com/sport/choupo-m...
# 2  https://www.channelnewsasia.com/sport/chelsea-...
# 3  https://www.channelnewsasia.com/sport/nothing-...
# 4  https://www.channelnewsasia.com/sport/contes-c...
#
#                                                 text nltk_location  \
# 0  LONDON :Seven-time winners AC Milan reached th...
# 1  MUNICH :Bayern Munich forward Eric-Maxim Choup...        Bayern
# 2  LONDON: Chelsea's Guro Reiten scored from the ...
# 3  LONDON: AC Milan can dare to dream about going...
# 4  LONDON: Antonio Conte's dismal record in the C...
#
#                                             nltk_gpe  \
# 0                                Tottenham, European
# 1  MUNICH, Germans, Paris, Bayern, Europe, French...
# 2    Brighton, United, Chelsea, Norway, Blues, Women
# 3             London, Europe, European, Milan, Serie
# 4                  Tottenham, London, Italian, Italy
#
#                                          nltk_person  \
# 0  Tottenham, Antonio Conte, Cristian Romero, Mil...
# 1  Bayern Munich, Serge Gnabry, Paris St Germain,...
# 2  Chelsea, Guro Reiten, Johanna Rytting Kaneryd,...
# 3  Milan, Stefano Pioli, Tottenham Hotspur, Pioli...
# 4  Antonio Conte, Conte, Juventus, Chelsea, Totte...
#
#                                             nltk_org
# 0  AC Milan, Champions League, Tottenham Hotspur,...
# 1  Champions League, PSG, VfB Stuttgart, Sommer, ...
# 2                   Super League, Jess Carter, Swede
# 3                          Champions League, AS Roma
# 4  Champions League, Tottenham Hotspur, AC Milan,...

# %% [markdown]
# spacy

# %%
#extract entities using above defined function
cont = cna['text'].tolist()

cna_list = spacy_ner(cont)
    
print(cna_list)
# Out:
# [[['LONDON', 'GPE'], ['AC Milan', 'ORG'], ['London', 'GPE'], ['Tottenham', 'GPE'], ['Tottenham', 'GPE'], ['Antonio Conte', 'PERSON'], ['Romero', 'PERSON'], ['Milan', 'GPE'], ["Stefano Pioli's", 'PERSON'], ['Milan', 'GPE'], ['Tottenham', 'GPE'], ['Sheffield United', 'GPE'], ['Wolverhampton Wanderers', 'PERSON'], ['Milan', 'GPE'], ['Pioli', 'GPE'], ['Tottenham', 'ORG'], ['Pioli', 'GPE'], ['GEAR', 'ORG'], ['Tottenham', 'GPE'], ['Tottenham', 'ORG'], ['Harry Kane', 'PERSON'], ['Son Heung-min', 'PERSON'], ['Dejan Kulusevski', 'PERSON'], ['Milan', 'GPE'], ['Brahim Diaz', 'PERSON'], ['Fraser Forster', 'GPE'], ['Tottenham', 'GPE'], ['Milan', 'GPE'], ['Mike Maignan', 'PERSON'], ['Pierre-Emile Hojbjerg', 'PERSON'], ['Tottenham', 'ORG'], ['Rafael Leao', 'PERSON'], ['Kane', 'PERSON'], ['Tottenham', 'GPE'], ['Richarlison', 'PERSON'], ['Emerson', 'ORG'], ['Conte', 'PERSON'], ['Kulusevski', 'PERSON'], ['Davinson Sanchez', 'PERSON'], ['Kane', 'PERSON'], ['Maignan', 'PERSON'], ['Milan', 'GPE'], ['Divock Origi', 'PERSON']], [['Bayern Munich', 'PERSON'], ['Eric-Maxim Choupo-Moting', 'PERSON'], ['Serge Gnabry', 'PERSON'], ['Paris', 'GPE'], ['Choupo-Moting', 'ORG'], ["Leon Goretzka's", 'PERSON'], ['Gnabry', 'PERSON'], ['Paris', 'GPE'], ['Messi', 'PERSON'], ['Kylian Mbappe', 'PERSON'], ['Julian Nagelsmann', 'PERSON'], ['Europe', 'LOC'], ['Neymar', 'GPE'], ['Mbappe', 'ORG'], ['Messi', 'GPE'], ["Jamal Musiala's", 'PERSON'], ['Gianluigi Donnarumma', 'PERSON'], ['Marquinhos', 'PERSON'], ['Yann Sommer', 'PERSON'], ['Vitinha', 'PERSON'], ['Matthijs de Ligt', 'ORG'], ['Mbappe', 'ORG'], ['Choupo-Moting', 'ORG'], ["Sergio Ramos's", 'PERSON'], ['Sommer', 'PERSON'], ['Gnabry', 'PERSON'], ['Bayern', 'ORG']], [['LONDON', 'GPE'], ['Chelsea', 'ORG'], ['Johanna Rytting Kaneryd', 'PERSON'], ['Brighton & Hove Albion', 'ORG'], ["Women's Super League", 'ORG'], ['Manchester United', 'GPE'], ['Chelsea', 'ORG'], ['Norway', 'GPE'], ['Chelsea', 'ORG'], ['Sam Kerr', 'PERSON'], ['Jess Carter', 'PERSON'], ['Kerr', 'PERSON'], ['Kaneryd', 'PERSON'], ['Brighton', 'GPE'], ['Danielle Carter', 'PERSON'], ['Leicester City', 'GPE'], ['Arsenal', 'ORG'], ['Chelsea', 'PERSON'], ["the Women's League Cup", 'ORG'], ['Liverpool', 'GPE'], ['Stina Blackstenius', 'PERSON'], ['Caitlin Foord', 'PERSON']], [['LONDON', 'GPE'], ['AC Milan', 'ORG'], ['the Champions League', 'ORG'], ['Stefano Pioli', 'PERSON'], ['Milan', 'GPE'], ['London', 'GPE'], ['Pioli', 'GPE'], ['Europe', 'LOC'], ['Milan', 'GPE'], ['Serie A', 'ORG'], ['Champions League', 'ORG'], ['the Champions League', 'ORG'], ['Milan', 'GPE'], ['Serie A', 'ORG'], ['Pioli', 'GPE'], ['Milan', 'GPE'], ['Chelsea', 'ORG'], ['Bayern Munich', 'PERSON'], ['Benfica', 'PERSON'], ['Tottenham', 'GPE'], ['Serie A', 'ORG']], [['LONDON', 'GPE'], ["Antonio Conte's", 'PERSON'], ['Champions League', 'ORG'], ['AC Milan', 'ORG'], ['Conte', 'PERSON'], ['London', 'GPE'], ['Champions League', 'ORG'], ['Juventus', 'ORG'], ['Inter Milan', 'ORG'], ['Chelsea', 'ORG'], ['Tottenham', 'GPE'], ['the Premier League', 'ORG'], ['Conte', 'PERSON'], ['Italy', 'GPE'], ['Amazon Prime', 'GPE'], ['Tottenham', 'ORG'], ['Conte', 'PERSON'], ['Tottenham', 'ORG'], ['the Europa Conference League', 'ORG'], ['Sheffield United', 'GPE'], ['Wolverhampton Wanderers', 'PERSON'], ['the Premier League', 'ORG'], ['Milan', 'GPE'], ['Conte', 'PERSON'], ['Conte', 'PERSON'], ['Tottenham', 'GPE'], ['Tottenham', 'GPE']], [['MUNICH', 'GPE'], ['Germany', 'GPE'], ['Paris', 'GPE'], ['Bayern Munich', 'PERSON'], ['the Champions League', 'ORG'], ['Kylian Mbappe', 'PERSON'], ['Messi', 'PERSON'], ['Bayern', 'ORG'], ['Europe', 'LOC'], ['France', 'GPE'], ['Mbappe', 'ORG'], ['Messi', 'PERSON'], ['Eric-Maxim Choupo-Moting', 'PERSON'], ['Serge Gnabry', 'PERSON'], ['Bayern', 'ORG'], ['Galtier', 'PERSON']], [['Manchester City', 'GPE'], ['Brazil', 'GPE'], ['Sporting', 'GPE'], ['Europa League', 'GPE'], ['Fabio Vieira', 'PERSON'], ['Sporting', 'GPE'], ['Kieran Tierney', 'PERSON'], ['Leandro Trossard', 'PERSON'], ['Ruben Amor ...

# %%
# sort according to entities
sort = spacy_sorting(cna_list)

print(sort[0])
print()

print(sort[1])
print()

print(sort[2])
print()

print(sort[3])
# Out:
# [['AC Milan', 'Tottenham', 'GEAR', 'Emerson'], ['Choupo-Moting', 'Mbappe', 'Matthijs de Ligt', 'Bayern'], ['Chelsea', 'Brighton & Hove Albion', "Women's Super League", 'Arsenal', "the Women's League Cup"], ['AC Milan', 'the Champions League', 'Serie A', 'Champions League', 'Chelsea'], ['Champions League', 'AC Milan', 'Juventus', 'Inter Milan', 'Chelsea', 'the Premier League', 'Tottenham', 'the Europa Conference League'], ['the Champions League', 'Bayern', 'Mbappe'], [], ['the PGA Tour', 'a Hall of Fame', 'Sawgrass', 'PGA Tour Player', 'TRIUMPH\r\n\r\nMcIlroy', "the PGA Tour's", 'Scheffler', 'PGA Tour', 'LIV Golf', 'top-10', 'TPC Sawgrass', 'Anirban Lahiri'], ['Woods'], ['Indian Wells', 'Grand Slam'], ['Commonwealth Sport Canada', 'CSC', "Commonwealth Sport Canada's", 'the Alberta 2030 Commonwealth Games Corporation', 'the Commonwealth Games Federation'], ['WELLS', 'Netflix'], ['Juventus', "Juventus' Europa League last-16", 'Pogba', 'Manchester United', 'Serie A.'], ['Mercedes', 'Bahrain Grand Prix', "BBC Radio 5 Live's", "Formula One's", 'BBC', 'Toto Wolff', "Red Bull's"], ['Super League', 'the Football Association and Professional Footballers Association', 'Chelsea', 'Sky Sports', "Women's Super League", 'ACL'], ['District Court', 'the Dutch football association', 'UEFA'], ['Champions League', 'Paris St Germain', 'UEFA', 'Parc de Princes'], ['BBC', 'Lineker', 'Channel', 'Nazi Germany', 'Braverman', 'Reuters', 'the Foxes, Everton,', "English Football's", 'Midway'], ['Corinne Diacre', 'The French Football Federation', 'FFF', 'FFF commission'], ['MANCHESTER', "the Women's World Cup", "International Women's Day", 'PE', 'Instagram', 'International Tennis Federation', 'a United Nations HeForShe Champion', 'Advantage All Male Allies', 'World Athletics'], ['Parker', 'Fulham', 'Briton'], ['the ATP Tour', 'Adelaide'], ["Manchester United's", 'Ajax Amsterdam', 'Old Trafford', 'Cristiano Ronaldo', 'the Europa League', 'the Premier League', 'United', 'Ten Hag'], ['Manchester United', 'Sven Botman', 'United', 'Botman', 'Wembley', 'Bruno Fernandes'], ['The Korea Football Association', 'KFA', 'Klinsmann'], ['Skipp', 'Kepa Arrizabalaga', 'Chelsea'], ['Mbappe', 'PSG', 'Marseille', 'Monaco', 'Nice', 'Montpellier', 'Marquinhos', "Nuno Tavares's", 'Nantes', 'the Parc des Princes'], ['LaLiga', 'Real Madrid', 'Atletico Madrid', 'the Europa League', 'Barca', 'Malian', 'Marc-Andre'], ['BOLOGNA', 'Inter Milan', 'Serie A', 'Inter', "Simone Inzaghi's", 'AC Milan', 'AS Roma', 'Milan Skriniar', 'Champions League', 'Alessandro Bastoni', 'Dominguez', 'DAZN'], ['Al Duhail', 'the Asian Champions League', 'Urawa Red Diamonds', 'Ighalo put Al Hilal', 'Manchester United', 'Al Ittihad'], ["Manchester United's", 'Sven Botman', 'United', 'the Europa League'], ['Premier League', 'Championship', 'Guardiola', 'Bournemouth'], [], ["Red Bull's", 'Formula One', 'Ferrari', 'Mercedes', 'Sauber/Alfa Romeo', 'McLaren', 'Williams', 'FERRARI', 'Vasseur', 'Alpine', 'Nyck de Vries', 'Red Bull-owned', 'AlphaTauri', 'Logan Sargeant', 'Haas', 'TEAMS', 'Andretti Cadillac', 'Red Bull', 'FIA'], [], ['Noel Le Graet', 'FFF', 'the Sports ministry', 'Le Graet', "Women's World Cup", 'RMC Sport', 'Renard', 'Clermont', 'the European Championship', "The Women's World Cup"], [], ['Grand Slam'], [], ['Cricbuzz', 'Adelaide Strikers', 'the Big Bash League'], [], ['Besiktas', 'The Turkish Super Lig'], ['MADRID', 'Real Madrid', 'Pedri', 'the Europa League', 'LaLiga', 'TVE', 'VAR'], ['the Dubai Tennis Championships', 'Hurkacz', 'ATP'], ['Formula One', "Alonso's", 'Renault', 'Alpine', 'Fernando', 'Ferrari', 'Alonso', 'AlphaTauri', 'Nyck de Vries', 'Monza'], [], ['Mercedes', 'Netflix'], ['Formula One', 'Mercedes', 'Hill', 'the Daily Telegraph', 'Independent', "Red Bull's"], ['MADRID', 'Goldman Sachs', 'KBRA', 'Nou Camp', 'BBB+ to BBB', 'Limak', 'Barca', 'LaLiga', 'Paris St Germain', 'La Liga TV', 'Socios.com'], ['Major League Baseball', 'MLB', 'St Louis Cardinals', 'Brook', 'Cardinals', 'the Chicago C ...
#
# [['LONDON', 'London', 'Tottenham', 'Milan', 'Sheffield United', 'Pioli', 'Fraser Forster'], ['Paris', 'Neymar', 'Messi'], ['LONDON', 'Manchester United', 'Norway', 'Brighton', 'Leicester City', 'Liverpool'], ['LONDON', 'Milan', 'London', 'Pioli', 'Tottenham'], ['LONDON', 'London', 'Tottenham', 'Italy', 'Amazon Prime', 'Sheffield United', 'Milan'], ['MUNICH', 'Germany', 'Paris', 'France'], ['Manchester City', 'Brazil', 'Sporting', 'Europa League', 'Tottenham', 'Portugal'], ['Ponte Vedra Beach', 'Florida', 'Smith'], ['Florida', 'Martin County', 'US', 'New York'], ['Calif.', 'Doha', 'Dubai'], ['Alberta', 'Calgary', 'Canada', 'Australia', 'Victoria', 'Birmingham', 'Durban', 'South Africa'], ['Florida', 'Canada', 'U.S.', 'Netflix'], ['Freiburg', 'Torino', 'Turin', 'Germany'], ['LONDON', 'Bahrain'], ['Germany', 'Australia', 'New Zealand'], ['Europa League'], ['Champions League'], ['England', 'Britain', 'Leicester City', 'Barcelona'], ['France', 'Diacre', 'Katoto', 'Kadidiatou Diani', 'New Zealand', 'Australia', 'Jamaica', 'Brazil', 'Panama', 'Canada', 'Spain'], ['England', 'Haiti', 'Morocco', 'Panama', 'Philippines', 'Portugal', 'Ireland', 'Vietnam', 'Zambia', 'Australia', 'New Zealand', 'US', 'UK', 'Britain', 'Canada'], ['the Champions League', 'Brugge', 'Champions League'], ['Dubai'], ['LONDON', "Newcastle United's", 'Barcelona', 'Manchester City', 'Casemiro', 'Newcastle'], ['LONDON', "Newcastle United's", 'Casemiro', 'Newcastle', 'Saudi Arabia', 'Europa League'], ['South Korea', 'Germany', "South Korea's", 'Brazil', 'the United States', 'Canada', 'Mexico', 'US', 'Colombia'], ['LONDON', 'Spurs'], ['Paris', 'Neymar', 'France', 'Messi', 'Argentina', 'Monaco', 'Lille', 'Achilles', 'Ligue', 'Champions League last-16'], ['Spain', 'Barcelona', 'Almeria', 'El Bilal', 'La Liga'], ['Italy', 'Napoli', 'Romelu Lukaku', 'Onana'], ['Qatar', 'Doha', 'Japan', 'Salem', 'Saudi Arabia', 'Urawa'], ['Casemiro', 'Rashford'], ['Manchester City', 'Bristol City', 'Leicester'], ['South Africa', 'Zimbabwe', 'Australia', 'Gqeberha'], ['Las Vegas', 'U.S.', 'Bahrain', 'the United States', 'LAS VEGAS', 'America'], ['Bahrain', 'Abu Dhabi', 'Las Vegas', 'U.S.', 'China', 'France', 'Qatar', 'Azerbaijan', 'Austria', 'Belgium', 'Austin', 'Brazil', 'Jeddah', 'Melbourne', 'Baku', 'Imola', 'Barcelona', 'Silverstone', 'Suzuka', 'Interlagos'], ['PARIS', 'France', 'Diacre', 'Katoto', 'Kadidiatou Diani', 'Norway', 'Denmark', 'Uruguay', 'England', 'Germany', 'Australia', 'New Zealand'], ['South Africa', 'Australia', 'England', 'Highveld', 'Pretoria'], ['Dubai', 'Texas'], ["New Zealand's", 'England', 'Wellington', 'Tauranga', 'New Zealand'], ['Spain', 'Thunder'], ['Australia', 'India', 'New Delhi'], ['Turkey', 'Syria'], ['Barcelona', 'Madrid', 'Kessie', 'Bilbao', 'Osasuna'], ['Adelaide', 'Dubai', 'Cincinnati'], ['Bahrain', 'Melbourne', 'US'], ['South Africa', 'England', 'Australia', 'Pakistan', 'Bangladesh'], ['Bahrain', 'Saudi Arabia'], ['Bahrain', 'Button'], ['Barcelona', 'Spotify', 'US'], ['England', 'Florida'], ['California'], ['LONDON', 'Italy', 'Germany', 'Bundesliga'], ['LONDON', 'London', 'Bundesliga'], [], ['Rosario', 'Argentina', 'Messi', 'Qatar', 'Panama', 'Estero', 'Curacao'], ['Argentina', 'Panama', 'Curacao', 'France', 'Qatar'], ['England', 'U.S.', 'Newcastle', "Saudi Arabia's", 'UK', 'Qatar', 'the Kingdom of Saudi Arabia'], ['Miami', 'Austin', 'U.S.'], ['Roma', 'Atalanta', 'France', 'Torino', 'Milan'], ['Leicester City', 'Sheffield United'], ['Cambodia'], ['Singapore', 'Saudi Arabia', 'Thailand'], ['the United States', 'Russia', 'Belarus', 'Moscow', 'Ukraine', 'Dubai'], ['Dubai', 'Netherlands', 'Doha', 'Melbourne'], ['Acapulco', 'U.S.', 'Mexico'], ['Miami', 'US'], ['England', 'Manchester City', 'Bristol City', "Leicester City's", 'Leeds United', 'Stoke City'], ['Liverpool', 'Anfield', 'Portugal'], ['LONDON', 'Bahrain', 'Saudi Arabia', 'Britain', 'London', 'US'], ['Sweden', 'France', 'Argentina', 'Qatar', 'Brazil', 'West Germany', "Only Germany's", 'Hungary', ' ...
#
# [['Antonio Conte', 'Romero', "Stefano Pioli's", 'Wolverhampton Wanderers', 'Harry Kane', 'Son Heung-min', 'Dejan Kulusevski', 'Brahim Diaz', 'Mike Maignan', 'Pierre-Emile Hojbjerg', 'Rafael Leao', 'Kane', 'Richarlison', 'Conte', 'Kulusevski', 'Davinson Sanchez', 'Maignan', 'Divock Origi'], ['Bayern Munich', 'Eric-Maxim Choupo-Moting', 'Serge Gnabry', "Leon Goretzka's", 'Gnabry', 'Messi', 'Kylian Mbappe', 'Julian Nagelsmann', "Jamal Musiala's", 'Gianluigi Donnarumma', 'Marquinhos', 'Yann Sommer', 'Vitinha', "Sergio Ramos's", 'Sommer'], ['Johanna Rytting Kaneryd', 'Sam Kerr', 'Jess Carter', 'Kerr', 'Kaneryd', 'Danielle Carter', 'Chelsea', 'Stina Blackstenius', 'Caitlin Foord'], ['Stefano Pioli', 'Bayern Munich', 'Benfica'], ["Antonio Conte's", 'Conte', 'Wolverhampton Wanderers'], ['Bayern Munich', 'Kylian Mbappe', 'Messi', 'Eric-Maxim Choupo-Moting', 'Serge Gnabry', 'Galtier'], ['Fabio Vieira', 'Kieran Tierney', 'Leandro Trossard', 'Ruben Amorim'], ['Jon Rahm', 'Cameron Smith', 'Johnny Miller', 'Scottie Scheffler', 'Rory McIlroy', 'McIlroy', 'Rahm', 'Max Homa', 'Homa', 'LIV Golf', 'Dustin Johnson', 'Paul Casey', 'Harold Varner III'], ["Tiger Woods'", 'Erica Herman', 'Herman', 'Joe Biden', 'Benjamin Hodas', 'Hodas'], ['Iga Swiatek'], ['Edmonton', 'Hamilton', 'Claire Carver-Dias', 'Roger Jackson', 'Jackson', 'Jyoti Gondek', 'Gondek'], ['Netflix', 'Casper Ruud', 'Felix Auger', 'Taylor Fritz', 'Ruud', 'Fritz', 'Maria'], ["Paul Pogba's"], ['Lewis Hamilton', 'Briton', 'Hamilton', 'Chequered Flag', 'Max Verstappen', 'Sergio Perez', "Aston Martin's", 'Fernando Alonso'], ['Chelsea', 'Melanie Leupolz', 'Leupolz', 'Emma Hayes', 'Emma', 'Hayes', 'Melanie'], ['Sevilla', 'Marko Dmitrovic', 'Eindhoven'], ['Bayern Munich'], ['Gary Lineker', 'Brexit', 'Twitter', 'Suella Braverman', 'Lineker', 'Nagoya Grampus', 'Bobby Charlton', 'Wayne Rooney', 'Harry Kane'], ['Wendie Renard', 'Renard', 'Diacre', 'Jul'], ['Fatma Samoura', 'Samoura', 'Hayley Wickenheiser', 'David Haggerty', 'Haggerty', 'Sebastian Coe'], ['Scott Parker', 'Englishman', 'Club Brugge', 'Bournemouth', 'Carl Hoefkens'], ['Novak Djokovic', 'Rafa Nadal', 'Tomas Machac'], ['Wembley', 'Erik ten Hag', 'Glazer', 'Brentford', 'Marcus Rashford', 'Lisandro Martinez', 'Raphael Varane', 'Antony', 'Wout Weghorst'], ['Eddie Howe', "Erik ten Hag's", 'Jose Mourinho', 'Bruno Fernandes', 'Brazilian Casemiro', 'Luke Shaw', 'Loris Karius', 'Marcus Rashford'], ['Juergen Klinsmann', 'Klinsmann', 'Paulo Bento', 'Gus Hiddink', 'Bayern Munich'], ['Chelsea', 'Oliver Skipp', 'Harry Kane', 'Spurs', 'Graham Potter', 'Enzo Fernandez', 'Kane', 'Son Heung-min', 'Eric Dier', 'Newcastle United'], ['Messi', 'Kylian Mbappe', 'Olympique de Marseille', 'Edinson Cavani', 'Sergio Ramos', 'Igor Tudor', 'Terem Moffi', 'Khephren Thuram', 'RC Lens', 'Presnel Kimpembe', 'Matteo Guendouzi', 'Mbappe', 'Pau Lopez', 'Bayern Munich'], ['Barca', 'Luis Suarez', "Leo Baptistao's", 'Rodrigo Ely', 'Xavi Hernandez'], ['Bologna', "Riccardo Orsolini's", 'Roberto Soriano', 'Andre Onana', "Andrea Cambiaso's", 'Federico Dimarco', 'Joaquin Correa', 'Nicolo Barella', 'Porto', 'Lautaro Martinez', 'Henrikh Mkhitaryan', 'Edin Dzeko', "Jerdy Schouten's", 'Nerazzurri'], ['Moussa Marega', 'Al Dawsari', 'Al Hilal', "Maciej Skorza's", "Mohammed Kanno's", 'Salah Zakaria', 'Michael Oliveira', 'Jang Hyun-soo', 'Marega', "Al Dawsari's", 'Mali', "Abdullah Al Mauoif's", 'Porto', 'Al Duhail', "Abdullah Al Hamdan's"], ['Newcastle United', 'Marcus Rashford', 'Trafford'], ['Pep Guardiola', 'Nigel Pearson', 'Bournemouth 4-1', 'Guardiola', 'Kevin De Bruyne', 'John Stones', 'Aymeric Laporte'], ['Kraigg Brathwaite', 'Brathwaite'], ['Max Verstappen', 'Lewis Hamilton', 'Sergio Perez', 'Fred Vasseur', 'Mattia Binotto', 'McLaren', 'Andreas Seidl', 'Sauber', 'Andrea Stella', 'James Vowles', 'Frenchman', 'Jean Todt', 'Michael Schumacher', 'Pierre Gasly', 'Williams', 'Alexander Rossi', 'Nico Hulkenberg', "Aston Martin's", 'Fernando Alonso', 'Hamilton'], ['Spielberg'], ['Ameli ...
#
# [[], ['Europe'], [], ['Europe'], [], ['Europe'], [], ['Bay Hill'], [], ['Southern California', 'Pole'], [], ['Indian Wells'], ['Europe'], [], [], [], [], [], [], [], ['Club Brugge'], [], [], [], [], [], [], ['Europe'], [], ['Al Thumama Stadium'], ['West Ham United'], [], ['West Indies', 'Caribbean'], ['Strip'], [], [], ['West Indies', 'the West Indies'], [], ['Basin Reserve'], ['The Isle of Man', "the Isle of Man's"], [], [], ['Ferran'], [], [], ['the West Indies'], [], [], ['Europe'], ['Europe', 'MLB Europe'], [], [], ['Europe'], [], [], [], ['Middle East'], [], [], ['West Ham United'], ['the SEA Games'], ['Asia'], [], [], [], ['Indian Wells'], ['Erling Haaland', 'West Ham United'], [], [], [], ['Sri Lanka', 'Mount Maunganui'], [], [], ['Marnus'], [], [], [], [], [], ['North America'], [], [], [], [], ['Indian Wells'], [], [], [], [], ['Mount Maunganui'], [], [], [], [], [], ['Bealham'], ['West Ham United'], [], ['West Indies', 'Caribbean'], [], [], [], [], ['West Ham United'], ['Europe'], ['Sakhir'], [], [], [], [], [], [], [], ['Hurricanes'], [], [], ['Europe'], [], [], [], [], [], ['Roland Garros'], ['Bay Hill'], ['Europe', 'Asia'], [], ['West Indies'], ['Ysaline Bonaventure'], ['the Otago Highlanders', 'Rebels'], [], [], [], [], ['Athletic Bilbao', 'Iker Muniain'], [], ['West Ham'], ['the Middle East'], [], []]

# %%
#append it to dataframe
cna['org_with_brac'] = sort[0]
cna['gpe_with_brac'] = sort[1]
cna['person_with_brac'] = sort[2]
cna['location_with_brac'] = sort[3]

cna['spacy_org']=cna['org_with_brac'].apply(lambda x: ','.join(map(str, x)))
cna['spacy_gpe'] = cna['gpe_with_brac'].apply(lambda x: ', '.join(map(str, x)))
cna['spacy_person'] = cna['person_with_brac'].apply(lambda x: ', '.join(map(str, x)))
cna['spacy_location'] = cna['location_with_brac'].apply(lambda x: ', '.join(map(str, x)))

cna = cna.drop(columns=['org_with_brac','gpe_with_brac','person_with_brac','location_with_brac'],axis = 1)

cna.head()
# Out:
#                                                  url  \
# 0  https://www.channelnewsasia.com/sport/steely-m...
# 1  https://www.channelnewsasia.com/sport/choupo-m...
# 2  https://www.channelnewsasia.com/sport/chelsea-...
# 3  https://www.channelnewsasia.com/sport/nothing-...
# 4  https://www.channelnewsasia.com/sport/contes-c...
#
#                                                 text nltk_location  \
# 0  LONDON :Seven-time winners AC Milan reached th...
# 1  MUNICH :Bayern Munich forward Eric-Maxim Choup...        Bayern
# 2  LONDON: Chelsea's Guro Reiten scored from the ...
# 3  LONDON: AC Milan can dare to dream about going...
# 4  LONDON: Antonio Conte's dismal record in the C...
#
#                                             nltk_gpe  \
# 0                                Tottenham, European
# 1  MUNICH, Germans, Paris, Bayern, Europe, French...
# 2    Brighton, United, Chelsea, Norway, Blues, Women
# 3             London, Europe, European, Milan, Serie
# 4                  Tottenham, London, Italian, Italy
#
#                                          nltk_person  \
# 0  Tottenham, Antonio Conte, Cristian Romero, Mil...
# 1  Bayern Munich, Serge Gnabry, Paris St Germain,...
# 2  Chelsea, Guro Reiten, Johanna Rytting Kaneryd,...
# 3  Milan, Stefano Pioli, Tottenham Hotspur, Pioli...
# 4  Antonio Conte, Conte, Juventus, Chelsea, Totte...
#
#                                             nltk_org  \
# 0  AC Milan, Champions League, Tottenham Hotspur,...
# 1  Champions League, PSG, VfB Stuttgart, Sommer, ...
# 2                   Super League, Jess Carter, Swede
# 3                          Champions League, AS Roma
# 4  Champions League, Tottenham Hotspur, AC Milan,...
#
#                                            spacy_org  \
# 0                    AC Milan,Tottenham,GEAR,Emerson
# 1       Choupo-Moting,Mbappe,Matthijs de Ligt,Bayern
# 2  Chelsea,Brighton & Hove Albion,Women's Super L...
# 3  AC Milan,the Champions League,Serie A,Champion...
# 4  Champions League,AC Milan,Juventus,Inter Milan...
#
#                                            spacy_gpe  \
# 0  LONDON, London, Tottenham, Milan, Sheffield Un...
# 1                               Paris, Neymar, Messi
# 2  LONDON, Manchester United, Norway, Brighton, L...
# 3            LONDON, Milan, London, Pioli, Tottenham
# 4  LONDON, London, Tottenham, Italy, Amazon Prime...
#
#                                         spacy_person spacy_location
# 0  Antonio Conte, Romero, Stefano Pioli's, Wolver...
# 1  Bayern Munich, Eric-Maxim Choupo-Moting, Serge...         Europe
# 2  Johanna Rytting Kaneryd, Sam Kerr, Jess Carter...
# 3              Stefano Pioli, Bayern Munich, Benfica         Europe
# 4    Antonio Conte's, Conte, Wolverhampton Wanderers

# %%
cna.to_csv('NER_data/cna_NER.csv')

# %% [markdown]
# ### Evaluation

# %%
path = r'../1.raw_data/golden_truth/golden_truth_cna.csv' # use your path

# import gold truth generated by chatgpt
cna_gold = pd.read_csv(path)
cna_gold = cna_gold.loc[:,['url','organisation','gpe','location','person']]
print(cna_gold.shape)
cna_gold
# Out:
# (50, 5)
#                                                   url  \
# 0   https://www.channelnewsasia.com/sport/djokovic...
# 1   https://www.channelnewsasia.com/sport/future-l...
# 2   https://www.channelnewsasia.com/sport/clinical...
# 3   https://www.channelnewsasia.com/sport/klinsman...
# 4   https://www.channelnewsasia.com/sport/spurs-be...
# 5   https://www.channelnewsasia.com/sport/psg-romp...
# 6   https://www.channelnewsasia.com/sport/la-liga-...
# 7   https://www.channelnewsasia.com/sport/inter-ti...
# 8   https://www.channelnewsasia.com/sport/ighalo-h...
# 9   https://www.channelnewsasia.com/sport/rashford...
# 10  https://www.channelnewsasia.com/sport/steely-m...
# 11  https://www.channelnewsasia.com/sport/choupo-m...
# 12  https://www.channelnewsasia.com/sport/talking-...
# 13  https://www.channelnewsasia.com/sport/formula-...
# 14  https://www.channelnewsasia.com/sport/french-f...
# 15  https://www.channelnewsasia.com/sport/new-skip...
# 16  https://www.channelnewsasia.com/sport/murray-p...
# 17  https://www.channelnewsasia.com/sport/williams...
# 18  https://www.channelnewsasia.com/sport/isle-man...
# 19  https://www.channelnewsasia.com/sport/australi...
# 20  https://www.channelnewsasia.com/sport/besiktas...
# 21  https://www.channelnewsasia.com/sport/lionel-m...
# 22  https://www.channelnewsasia.com/sport/pogba-ba...
# 23  https://www.channelnewsasia.com/sport/novak-dj...
# 24  https://www.channelnewsasia.com/sport/chelsea-...
# 25  https://www.channelnewsasia.com/sport/kyrgios-...
# 26  https://www.channelnewsasia.com/sport/french-p...
# 27  https://www.channelnewsasia.com/sport/world-cu...
# 28  https://www.channelnewsasia.com/sport/nothing-...
# 29  https://www.channelnewsasia.com/sport/contes-c...
# 30  https://www.channelnewsasia.com/sport/japan-au...
# 31  https://www.channelnewsasia.com/sport/england-...
# 32  https://www.channelnewsasia.com/sport/late-lui...
# 33  https://www.channelnewsasia.com/sport/horse-ra...
# 34  https://www.channelnewsasia.com/sport/canada-s...
# 35  https://www.channelnewsasia.com/sport/soccer-m...
# 36  https://www.channelnewsasia.com/sport/british-...
# 37  https://www.channelnewsasia.com/sport/olympic-...
# 38  https://www.channelnewsasia.com/sport/six-nati...
# 39  https://www.channelnewsasia.com/sport/psgs-gal...
# 40  https://www.channelnewsasia.com/sport/guardiol...
# 41  https://www.channelnewsasia.com/sport/brathwai...
# 42  https://www.channelnewsasia.com/sport/joseph-s...
# 43  https://www.channelnewsasia.com/sport/hsbc-wom...
# 44  https://www.channelnewsasia.com/sport/novak-dj...
# 45  https://www.channelnewsasia.com/sport/djokovic...
# 46  https://www.channelnewsasia.com/sport/top-seed...
# 47  https://www.channelnewsasia.com/sport/nadal-wi...
# 48  https://www.channelnewsasia.com/sport/foden-do...
# 49  https://www.channelnewsasia.com/sport/klopp-ho...
#
#                                          organisation  \
# 0                                            ATP Tour
# 1   Manchester United, Ajax Amsterdam, Barcelona, ...
# 2            Manchester United, Newcastle United, VAR
# 3   South Korea Football Association (KFA), Bayern...
# 4                          Tottenham Hotspur, Chelsea
# 5   Paris St Germain, Olympique de Marseille, RC L...
# 6   Barcelona, Real Madrid, Atletico Madrid, Europ...
# 7   Inter Milan, Napoli, Empoli, AC Milan, AS Roma...
# 8   Asian Champions League, Al Hilal, Al Duhail, U...
# 9    Manchester United, Newcastle United, Carabao Cup
# 10  AC Milan, Tottenham Hotspur, Champions League,...
# 11                    Bayern Munich, Paris St Germain
# 12  Red Bull, Ferrari, Sauber/Alfa Romeo, McLaren,...
# 13                                        Formula One
# 14                   French Football Federation (FFF)
# 15                        South African cricket team.
# 16                    ATP, Dubai Tennis Championships
# 17                                                NaN
# 18                                     Sydney Thunder
# 19         Australia cricket team, India cricket team
# 20                                           Besiktas
# 21  FIFA, Ballon d'Or organisers France Football, ...
# 22                                           Juventus
# 23                                       ATP Rankings
# 24  AC Milan, Tottenham Hotspur, AS Roma, Chelsea,...
# 25                                                ATP
# 26            Paris Saint-Germain (PSG), FIFA, FIFPro
# 27                               Argentina's FA, FIFA
# 28  AC Milan, Tottenham Hotspur, AS Roma, Chelsea,...
# 29  Tottenham Hotspur, AC Milan, Juventus, Inter M...
# 30  Fair Trade Commission, Dentsu, Hakuhodo DY Hol...
# 31                                         Black Caps
# 32   Lazio, AS Roma, Inter Milan, AC Milan, Sampdoria
# 33  Horseracing Integrity and Safety Authority (HI...
# 34  Canada Soccer, men's and women's national team...
# 35  FIFA, Paris Saint-Germain, Ballon d'Or, France...
# 36                 FIS (International Ski Federation)
# 37                                     Populist Party
# 38                  Irish Rugby Football Union (IRFU)
# 39  Paris St Germain, Bayern Munich, Champions League
# 40                                    Manchester City
# 41  West Indies cricket team, South Africa cricket...
# 42                              Southeast Asian Games
# 43                    HSBC Women's World Championship
# 44                               Wimbledon Grand Slam
# 45               ATP Tour, Dubai Tennis Championships
# 46                                                ATP
# 47                                  BNP Paribas Open.
# 48  Manchester City, Leicester City, Blackburn Rov...
# 49  Liverpool FC, Wolverhampton Wanderers, Tottenh...
#
#                                                   gpe  \
# 0                              Serbia, Czech Republic
# 1                                    London, Wembley.
# 2                       London, Wembley, Saudi Arabia
# 3   South Korea, Germany, United States, Canada, M...
# 4                                              London
# 5                                              France
# 6                                               Spain
# 7                                               Italy
# 8                    Qatar, Doha, Saudi Arabia, Japan
# 9   Manchester United, Newcastle, and West Ham United
# 10                                              Italy
# 11                                    Germany, France
# 12                                          Las Vegas
# 13  Bahrain, Las Vegas, China, France, Qatar, Aust...
# 14                                             France
# 15                                           Pretoria
# 16                                              Dubai
# 17                                                NaN
# 18                                              Spain
# 19                                   India, Australia
# 20   Antalyaspor, Ghana, Vodafone Park, Turkey, Syria
# 21  Argentina, France, United States, Spain, Engla...
# 22                                     France, Torino
# 23  Spain, Australian Open, Dubai Duty Free Tennis...
# 24                                                NaN
# 25                                          Australia
# 26                        France, Morocco, Arab world
# 27                                          Argentina
# 28                 Champions League, Milan, Tottenham
# 29                                     Premier League
# 30  Fair Trade Commission, Dentsu, Hakuhodo DY Hol...
# 31                                                NaN
# 32                                             Napoli
# 33                                                NaN
# 34                                     SheBelievesCup
# 35  Argentina, Spain, England, United States, Hung...
# 36                        Britain, New Zealand, Japan
# 37                                      United States
# 38                                              Italy
# 39                                             France
# 40                                            England
# 41                                        West Indies
# 42                             Singapore and Cambodia
# 43                                  Sentosa Golf Club
# 44                   Serbia, Russia, Belarus, Ukraine
# 45                                        Netherlands
# 46                                            Spanish
# 47                                          US, Spain
# 48                       Premier League, Championship
# 49                                     Premier League
#
#                                              location  \
# 0                     Adelaide, Melbourne Park, Dubai
# 1                                        Old Trafford
# 2                                            Tyneside
# 3                                   the United States
# 4                                              London
# 5                                           Velodrome
# 6                                             Almeria
# 7                              Stadio Renato Dall'Ara
# 8                                  Al Thumama Stadium
# 9                                        Old Trafford
# 10                    London, north London, San Siro.
# 11                       Munich, Paris, VfB Stuttgart
# 12      Bahrain, Maranello, United States, Las Vegas.
# 13  United States, Singapore, Japan, Italy, Nether...
# 14  Paris, France, Norway, Denmark, Uruguay, Engla...
# 15  Centurion Park, Australia, England, Pretoria, ...
# 16                                Dubai, Qatar, Texas
# 17  Wellington's Basin Reserve, Tauranga, New Zeal...
# 18                       Isle of Man, Spain, Adelaide
# 19                       Bengaluru, Indore, New Delhi
# 20                                      Turkey, Syria
# 21  Paris, Doha, Lyon, England, Australia, New Zea...
# 22                                Monza, Qatar, Italy
# 23                                                NaN
# 24                            London, Europe, Serie A
# 25   Indian Wells, Miami, Wimbledon, Japan, Australia
# 26              Nanterre, Paris, Qatar, Madrid, Spain
# 27       Paris, Canada, Mexico, United States, Russia
# 28                            London, Europe, Serie A
# 29                               London, north London
# 30                                       Tokyo, Japan
# 31  England, New Zealand, Wellington, Basin Reserv...
# 32                             Stadio Olimpico, Genoa
# 33            Louisiana, West Virginia, United States
# 34                                             Canada
# 35          Paris, Doha, Lyon, Australia, New Zealand
# 36  Bakuriani, Georgia, Beijing (implicitly mentio...
# 37                                Helsinki, Melbourne
# 38                 Dublin, Ireland, Scotland, England
# 39                                    Munich, Germany
# 40                                Manchester, Bristol
# 41  Centurion Park, South Africa, Zimbabwe, Austra...
# 42                                Singapore, Cambodia
# 43                  Singapore, Saudi Arabia, Thailand
# 44                    Australia, United States, Dubai
# 45                  Dubai, Melbourne, Rotterdam, Doha
# 46                   Acapulco, Rio Open, Buenos Aires
# 47  Indian Wells, Miami, Melbourne Park, Rod Laver...
# 48  Bristol, England, Leicester, Blackburn, Fulham...
# 49                 Liverpool, Anfield, Crystal Palace
#
#                                                person
# 0   Novak Djokovic, Rafa Nadal, Steffi Graf, Tomas...
# 1   Cristiano Ronaldo, Erik ten Hag, Marcus Rashfo...
# 2   Casemiro, Sven Botman, Eddie Howe, Erik ten Ha...
# 3         Juergen Klinsmann, Paulo Bento, Gus Hiddink
# 4   Oliver Skipp, Harry Kane, Enzo Fernandez, Kepa...
# 5   Lionel Messi, Kylian Mbappe, Neymar, Edinson C...
# 6   El Bilal Toure, Luis Suarez, Leo Baptistao, Ma...
# 7   Riccardo Orsolini, Musa Barrow, Roberto Sorian...
# 8   Odion Ighalo, Moussa Marega, Salem Al Dawsari,...
# 9              Marcus Rashford, Casemiro, Sven Botman
# 10  Antonio Conte, Stefano Pioli, Harry Kane, Son ...
# 11  Eric-Maxim Choupo-Moting, Serge Gnabry, Leon G...
# 12  Max Verstappen, Lewis Hamilton, Fred Vasseur, ...
# 13                                               None
# 14   Noel Le Graet, Zinedine Zidane, Didier Descha...
# 15  Temba Bavuma, Aiden Markram, Ryan Rickelton, T...
# 16                                        Andy Murray
# 17  Kane Williamson, Ross Taylor, James Anderson, ...
# 18                      Joseph Burrows, Corey Rutgers
# 19  Mitchell Starc, Pat Cummins, David Warner, Cam...
# 20                                     Christian Atsu
# 21  Lionel Messi, Alexia Putellas, Kylian Mbappe, ...
# 22  Paul Pogba, Massimiliano Allegri, Federico Chi...
# 23  Novak Djokovic, Steffi Graf, Carlos Alcaraz, M...
# 24                                      Stefano Pioli
# 25                                       Nick Kyrgios
# 26                       Achraf Hakimi, Kylian Mbappe
# 27  Lionel Scaloni, Claudio Tapia, Lionel Messi, J...
# 28                                      Stefano Pioli
# 29                                      Antonio Conte
# 30                    Goh Okumura, Haruyuki Takahashi
# 31  Joe Root, Ben Stokes, Ollie Robinson, Tim Sout...
# 32        Luis Alberto, Ciro Immobile, Maurizio Sarri
# 33                          Lisa Lazarus, Ben Mosier.
# 34                                        Nick Bontis
# 35  Lionel Messi, Alexia Putellas, Kylian Mbappe, ...
# 36  Mia Brookes, Zoi Sadowski-Synnott, Onitsuka Mi...
# 37                                       Bob Richards
# 38  Finlay Bealham, Tadhg Furlong, Johnny Sexton, ...
# 39  Christophe Galtier, Kylian Mbappe, Lionel Mess...
# 40      Pep Guardiola, Nigel Pearson, Kevin De Bruyne
# 41                                  Kraigg Brathwaite
# 42                                   Joseph Schooling
# 43  Lydia Ko, Nelly Korda, Minjee Lee, Ko Jin-youn...
# 44                       Novak Djokovic, Tomas Machac
# 45  Novak Djokovic, Tomas Machac, Steffi Graf, Tal...
# 46                     Carlos Alcaraz, Cameron Norrie
# 47      Rafa Nadal, Taylor Fritz, Mackenzie McDonald.
# 48  Phil Foden, Pep Guardiola, Kevin De Bruyne, Ty...
# 49  Juergen Klopp, Thiago Alcantara, Joe Gomez, Lu...

# %%
# joining gold truth data with extracted entities
eval_cna = cna.set_index('url').join(cna_gold.set_index('url'))
print(eval_cna.shape)
eval_cna.head()
# Out:
# (139, 13)
#                                                                                                  text  \
# url
# https://www.channelnewsasia.com/sport/abde-goal...  PAMPLONA, Spain : Moroccan forward Ez Abde sco...
# https://www.channelnewsasia.com/sport/ac-milan-...  LONDON: Italy's Serie A soccer league should a...
# https://www.channelnewsasia.com/sport/all-black...  New Zealand head coach Ian Foster said on Wedn...
# https://www.channelnewsasia.com/sport/alonso-pr...  MANAMA: Oscar Piastri was not yet born when Fe...
# https://www.channelnewsasia.com/sport/argentina...  BUENOS AIRES: Argentina will play their first ...
#
#                                                    nltk_location  \
# url
# https://www.channelnewsasia.com/sport/abde-goal...
# https://www.channelnewsasia.com/sport/ac-milan-...
# https://www.channelnewsasia.com/sport/all-black...
# https://www.channelnewsasia.com/sport/alonso-pr...
# https://www.channelnewsasia.com/sport/argentina...
#
#                                                                                            nltk_gpe  \
# url
# https://www.channelnewsasia.com/sport/abde-goal...     PAMPLONA, Spain, Bilbao, Barcelona, Pamplona
# https://www.channelnewsasia.com/sport/ac-milan-...        LONDON, Italy, Germany, Italian, New York
# https://www.channelnewsasia.com/sport/all-black...                              New Zealand, France
# https://www.channelnewsasia.com/sport/alonso-pr...  MANAMA, Bahrain, Australian, Melbourne, Piastri
# https://www.channelnewsasia.com/sport/argentina...               Argentina, Santiago, France, Qatar
#
#                                                                                           nltk_person  \
# url
# https://www.channelnewsasia.com/sport/abde-goal...                                      Abde, Osasuna
# https://www.channelnewsasia.com/sport/ac-milan-...             Serie, Milan, Gerry Cardinale, Serie A
# https://www.channelnewsasia.com/sport/all-black...                                 Ian Foster, Foster
# https://www.channelnewsasia.com/sport/alonso-pr...  Oscar Piastri, Fernando Alonso, Aston, Martin,...
# https://www.channelnewsasia.com/sport/argentina...  Panama, Curacao, Estero, Lionel Messi, Lionel ...
#
#                                                                                              nltk_org  \
# url
# https://www.channelnewsasia.com/sport/abde-goal...  Athletic Bilbao, Real Madrid, Basque Country, ...
# https://www.channelnewsasia.com/sport/ac-milan-...  AC, RedBird Capital, Financial Times Business,...
# https://www.channelnewsasia.com/sport/all-black...          Rugby, New Zealand Rugby, NZR, All Blacks
# https://www.channelnewsasia.com/sport/alonso-pr...  Formula One, Sakhir, FIA, Fernando Alonso, Fer...
# https://www.channelnewsasia.com/sport/argentina...  Lionel Scaloni, Monumental, Madre, Argentine, AFA
#
#                                                                                             spacy_org  \
# url
# https://www.channelnewsasia.com/sport/abde-goal...                               PAMPLONA,Real Madrid
# https://www.channelnewsasia.com/sport/ac-milan-...  Serie A,AC Milan,RedBird Capital,Serie A's,the...
# https://www.channelnewsasia.com/sport/all-black...                            the Rugby World Cup,NZR
# https://www.channelnewsasia.com/sport/alonso-pr...  Formula One,Alonso's,Renault,Alpine,Fernando,F...
# https://www.channelnewsasia.com/sport/argentina...                                                AFA
#
#                                                                                       spacy_gpe  \
# url
# https://www.channelnewsasia.com/sport/abde-goal...  Spain, Osasuna, Bilbao, Barcelona, Pamplona
# https://www.channelnewsasia.com/sport/ac-milan-...           LONDON, Italy, Germany, Bundesliga
# https://www.channelnewsasia.com/sport/all-black...                          New Zealand, France
# https://www.channelnewsasia.com/sport/alonso-pr...                       Bahrain, Melbourne, US
# https://www.channelnewsasia.com/sport/argentina...    Argentina, Panama, Curacao, France, Qatar
#
#                                                                                          spacy_person  \
# url
# https://www.channelnewsasia.com/sport/abde-goal...                                      Ez Abde, Abde
# https://www.channelnewsasia.com/sport/ac-milan-...                                    Gerry Cardinale
# https://www.channelnewsasia.com/sport/all-black...                                 Ian Foster, Foster
# https://www.channelnewsasia.com/sport/alonso-pr...  Oscar Piastri, Fernando Alonso, Aston Martin, ...
# https://www.channelnewsasia.com/sport/argentina...                                       Lionel Messi
#
#                                                                    spacy_location  \
# url
# https://www.channelnewsasia.com/sport/abde-goal...  Athletic Bilbao, Iker Muniain
# https://www.channelnewsasia.com/sport/ac-milan-...
# https://www.channelnewsasia.com/sport/all-black...
# https://www.channelnewsasia.com/sport/alonso-pr...
# https://www.channelnewsasia.com/sport/argentina...
#
#                                                    organisation  gpe location  \
# url
# https://www.channelnewsasia.com/sport/abde-goal...          NaN  NaN      NaN
# https://www.channelnewsasia.com/sport/ac-milan-...          NaN  NaN      NaN
# https://www.channelnewsasia.com/sport/all-black...          NaN  NaN      NaN
# https://www.channelnewsasia.com/sport/alonso-pr...          NaN  NaN      NaN
# https://www.channelnewsasia.com/sport/argentina...          NaN  NaN      NaN
#
#                                                    person
# url
# https://www.channelnewsasia.com/sport/abde-goal...    NaN
# https://www.channelnewsasia.com/sport/ac-milan-...    NaN
# https://www.channelnewsasia.com/sport/all-black...    NaN
# https://www.channelnewsasia.com/sport/alonso-pr...    NaN
# https://www.channelnewsasia.com/sport/argentina...    NaN

# %%
# Since we did not extract gold truth from chatgpt for all articles, we only keep those that has gold truth extracted.
eval_cna2 = eval_cna[ (eval_cna['organisation'].notna()) & (eval_cna['gpe'].notna()) & (eval_cna['location'].notna()) & (eval_cna['person'].notna())]
print(eval_cna2.shape)
eval_cna2.head()
# Out:
# (48, 13)
#                                                                                                  text  \
# url
# https://www.channelnewsasia.com/sport/australia...  BENGALURU :Australia pace man Mitchell Starc s...
# https://www.channelnewsasia.com/sport/besiktas-...  Besiktas fans threw thousands of stuffed toys ...
# https://www.channelnewsasia.com/sport/brathwait...  West Indies captain Kraigg Brathwaite believes...
# https://www.channelnewsasia.com/sport/brathwait...  West Indies captain Kraigg Brathwaite believes...
# https://www.channelnewsasia.com/sport/british-t...  Britain's Mia Brookes outclassed Olympic gold ...
#
#                                                              nltk_location  \
# url
# https://www.channelnewsasia.com/sport/australia...
# https://www.channelnewsasia.com/sport/besiktas-...
# https://www.channelnewsasia.com/sport/brathwait...  South Africa,Caribbean
# https://www.channelnewsasia.com/sport/brathwait...  South Africa,Caribbean
# https://www.channelnewsasia.com/sport/british-t...
#
#                                                                                              nltk_gpe  \
# url
# https://www.channelnewsasia.com/sport/australia...  Australia, India, Indore, Cummins, Indian, New...
# https://www.channelnewsasia.com/sport/besiktas-...                         Antalyaspor, Turkey, Ghana
# https://www.channelnewsasia.com/sport/brathwait...  West, Zimbabwe, Australia, South Africa, Brath...
# https://www.channelnewsasia.com/sport/brathwait...  West, Zimbabwe, Australia, South Africa, Brath...
# https://www.channelnewsasia.com/sport/british-t...  Britain, Bakuriani, Georgia, Briton, Brooks, N...
#
#                                                                                           nltk_person  \
# url
# https://www.channelnewsasia.com/sport/australia...  Starc, Pat Cummins, David Warner, Cameron Gree...
# https://www.channelnewsasia.com/sport/besiktas-...                           Besiktas, Christian Atsu
# https://www.channelnewsasia.com/sport/brathwait...                      Kraigg Brathwaite, Brathwaite
# https://www.channelnewsasia.com/sport/brathwait...                      Kraigg Brathwaite, Brathwaite
# https://www.channelnewsasia.com/sport/british-t...                               Zoi, Brooks, Brookes
#
#                                                                                              nltk_org  \
# url
# https://www.channelnewsasia.com/sport/australia...                                           Mitchell
# https://www.channelnewsasia.com/sport/besiktas-...                   Turkish Super Lig, Vodafone Park
# https://www.channelnewsasia.com/sport/brathwait...                             Indies, Centurion Park
# https://www.channelnewsasia.com/sport/brathwait...                             Indies, Centurion Park
# https://www.channelnewsasia.com/sport/british-t...  Mia Brookes, FIS, Freestyle Ski, Beijing Olymp...
#
#                                                                                             spacy_org  \
# url
# https://www.channelnewsasia.com/sport/australia...
# https://www.channelnewsasia.com/sport/besiktas-...                     Besiktas,The Turkish Super Lig
# https://www.channelnewsasia.com/sport/brathwait...
# https://www.channelnewsasia.com/sport/brathwait...
# https://www.channelnewsasia.com/sport/british-t...  FIS,Briton,Brooks,Sadowski-Synnott,Onitsuka Mi...
#
#                                                                                             spacy_gpe  \
# url
# https://www.channelnewsasia.com/sport/australia...                        Australia, India, New Delhi
# https://www.channelnewsasia.com/sport/besiktas-...                                      Turkey, Syria
# https://www.channelnewsasia.com/sport/brathwait...        South Africa, Zimbabwe, Australia, Gqeberha
# https://www.channelnewsasia.com/sport/brathwait...        South Africa, Zimbabwe, Australia, Gqeberha
# https://www.channelnewsasia.com/sport/british-t...  Britain, Bakuriani, Georgia, New Zealand's, Japan
#
#                                                                                          spacy_person  \
# url
# https://www.channelnewsasia.com/sport/australia...  Mitchell Starc, Pat Cummins, David Warner, Sta...
# https://www.channelnewsasia.com/sport/besiktas-...                              Ghana, Christian Atsu
# https://www.channelnewsasia.com/sport/brathwait...                      Kraigg Brathwaite, Brathwaite
# https://www.channelnewsasia.com/sport/brathwait...                      Kraigg Brathwaite, Brathwaite
# https://www.channelnewsasia.com/sport/british-t...          Mia Brookes, Zoi Sadowski-Synnott, Brooks
#
#                                                             spacy_location  \
# url
# https://www.channelnewsasia.com/sport/australia...
# https://www.channelnewsasia.com/sport/besiktas-...
# https://www.channelnewsasia.com/sport/brathwait...  West Indies, Caribbean
# https://www.channelnewsasia.com/sport/brathwait...  West Indies, Caribbean
# https://www.channelnewsasia.com/sport/british-t...
#
#                                                                                          organisation  \
# url
# https://www.channelnewsasia.com/sport/australia...         Australia cricket team, India cricket team
# https://www.channelnewsasia.com/sport/besiktas-...                                           Besiktas
# https://www.channelnewsasia.com/sport/brathwait...  West Indies cricket team, South Africa cricket...
# https://www.channelnewsasia.com/sport/brathwait...  West Indies cricket team, South Africa cricket...
# https://www.channelnewsasia.com/sport/british-t...                 FIS (International Ski Federation)
#
#                                                                                                  gpe  \
# url
# https://www.channelnewsasia.com/sport/australia...                                  India, Australia
# https://www.channelnewsasia.com/sport/besiktas-...  Antalyaspor, Ghana, Vodafone Park, Turkey, Syria
# https://www.channelnewsasia.com/sport/brathwait...                                       West Indies
# https://www.channelnewsasia.com/sport/brathwait...                                       West Indies
# https://www.channelnewsasia.com/sport/british-t...                       Britain, New Zealand, Japan
#
#                                                                                              location  \
# url
# https://www.channelnewsasia.com/sport/australia...                       Bengaluru, Indore, New Delhi
# https://www.channelnewsasia.com/sport/besiktas-...                                      Turkey, Syria
# https://www.channelnewsasia.com/sport/brathwait...  Centurion Park, South Africa, Zimbabwe, Austra...
# https://www.channelnewsasia.com/sport/brathwait...  Centurion Park, South Africa, Zimbabwe, Austra...
# https://www.channelnewsasia.com/sport/british-t...  Bakuriani, Georgia, Beijing (implicitly mentio...
#
#                                                                                                person
# url
# https://www.channelnewsasia.com/sport/australia...  Mitchell Starc, Pat Cummins, David Warner, Cam...
# https://www.channelnewsasia.com/sport/besiktas-...                                     Christian Atsu
# https://www.channelnewsasia.com/sport/brathwait...                                  Kraigg Brathwaite
# https://www.channelnewsasia.com/sport/brathwait...                                  Kraigg Brathwaite
# https://www.channelnewsasia.com/sport/british-t...  Mia Brookes, Zoi Sadowski-Synnott, Onitsuka Mi...

# %% [markdown]
# #### NLTK

# %% [markdown]
# Location

# %%
# locations from gold truth
true_loc = eval_cna2["location"].values.tolist()

new_true_loc = []
for x in true_loc:
    if len(x)>1:
        txt = x.split(",")
        for n in txt:
            if n != '':
                new_true_loc.append(n.lstrip())

print(new_true_loc)
# Out:
# ['Bengaluru', 'Indore', 'New Delhi', 'Turkey', 'Syria', 'Centurion Park', 'South Africa', 'Zimbabwe', 'Australia', 'Gqeberha', 'Centurion Park', 'South Africa', 'Zimbabwe', 'Australia', 'Gqeberha', 'Bakuriani', 'Georgia', 'Beijing (implicitly mentioned)', 'Canada', 'Munich', 'Paris', 'VfB Stuttgart', 'Tyneside', 'London', 'north London', 'Dubai', 'Melbourne', 'Rotterdam', 'Doha', 'Adelaide', 'Melbourne Park', 'Dubai', 'Adelaide', 'Melbourne Park', 'Dubai', 'Bristol', 'England', 'Leicester', 'Blackburn', 'Fulham', 'Leeds', 'Brighton and Hove', 'Stoke', 'Manchester', 'West Ham', 'United States', 'Singapore', 'Japan', 'Italy', 'Netherlands', 'Belgium', 'Hungary', 'Britain', 'Austria', 'Canada', 'Spain', 'Monaco', 'Emilia Romagna', 'Miami', 'Qatar', 'France', 'China', 'Saudi Arabia', 'Azerbaijan', 'Australia', 'Bahrain', 'Las Vegas', 'Abu Dhabi.', 'Paris', 'France', 'Norway', 'Denmark', 'Uruguay', 'England', 'Australia', 'New Zealand', 'Old Trafford', 'Manchester', 'Bristol', 'Manchester', 'Bristol', 'Singapore', 'Saudi Arabia', 'Thailand', 'Al Thumama Stadium', "Stadio Renato Dall'Ara", 'Isle of Man', 'Spain', 'Adelaide', 'Tokyo', 'Japan', 'Singapore', 'Cambodia', 'the United States', 'the United States', 'Liverpool', 'Anfield', 'Crystal Palace', 'Indian Wells', 'Miami', 'Wimbledon', 'Japan', 'Australia', 'Almeria', 'Stadio Olimpico', 'Genoa', 'Dubai', 'Qatar', 'Texas', 'Indian Wells', 'Miami', 'Melbourne Park', 'Rod Laver Arena.', 'Centurion Park', 'Australia', 'England', 'Pretoria', 'South Africa', 'West Indies.', 'London', 'Europe', 'Serie A', 'Australia', 'United States', 'Dubai', 'Helsinki', 'Melbourne', 'Monza', 'Qatar', 'Italy', 'Velodrome', 'Velodrome', 'Munich', 'Germany', 'Old Trafford', 'Old Trafford', 'Dublin', 'Ireland', 'Scotland', 'England', 'London', 'London', 'north London', 'San Siro.', 'Bahrain', 'Maranello', 'United States', 'Las Vegas.', 'Acapulco', 'Rio Open', 'Buenos Aires', 'Paris', 'Canada', 'Mexico', 'United States', 'Russia']

# %%
# locations extracted using NLTK
nltk_loc = eval_cna2['nltk_location'].values.tolist()

new_nltk_loc = []
for x in nltk_loc:
    if len(x)>1:
        txt = x.split(",")
        for n in txt:
            if n != '':
                new_nltk_loc.append(n.lstrip())

print(new_nltk_loc)
# Out:
# ['South Africa', 'Caribbean', 'South Africa', 'Caribbean', 'Bayern', 'West Ham United', 'South Korean', 'Southeast', 'West', 'West Ham United', 'West Ham United']

# %%
#nltk precision, recall, f1 score of location entity
correct = 0

for x in new_nltk_loc:
    if x in new_true_loc:
        correct+=1

nltk_loc_recall = correct/len(new_true_loc)
nltk_loc_precision = correct/len(new_nltk_loc)
nltk_loc_f1_score = 2*((nltk_loc_precision * nltk_loc_recall)/ (nltk_loc_precision + nltk_loc_recall))
    
print("Recall = ", nltk_loc_recall)
print()
print("Precision = ", nltk_loc_precision)
print()
print("f1 score = ", nltk_loc_f1_score)
# Out:
# Recall =  0.01282051282051282
#
# Precision =  0.18181818181818182
#
# f1 score =  0.02395209580838323

# %% [markdown]
# GPE

# %%
# GPE from gold truth
true_gpe = eval_cna2["gpe"].values.tolist()

new_true_gpe = []
for x in true_gpe:
    if len(x)>1:
        txt = x.split(",")
        for n in txt:
            if n != '':
                new_true_gpe.append(n.lstrip())

print(new_true_gpe)
# Out:
# ['India', 'Australia', 'Antalyaspor', 'Ghana', 'Vodafone Park', 'Turkey', 'Syria', 'West Indies', 'West Indies', 'Britain', 'New Zealand', 'Japan', 'SheBelievesCup', 'Germany', 'France', 'London', 'Wembley', 'Saudi Arabia', 'Premier League', 'Netherlands', 'Serbia', 'Czech Republic', 'Serbia', 'Czech Republic', 'Premier League', 'Championship', 'Bahrain', 'Las Vegas', 'China', 'France', 'Qatar', 'Australia', 'Azerbaijan', 'Miami', 'Emilia Romagna', 'Monaco', 'Spain', 'Canada', 'Austria', 'Britain', 'Hungary', 'Belgium', 'Netherlands', 'Italy', 'Singapore', 'Japan', 'United States', 'Mexico', 'Brazil', 'Abu Dhabi', 'Jeddah', 'Montreal', 'Spielberg', 'Silverstone', 'Spa-Francorchamps', 'Zandvoort', 'Interlagos', 'Suzuka', 'and Monza.', 'France', 'London', 'Wembley.', 'England', 'England', 'Sentosa Golf Club', 'Qatar', 'Doha', 'Saudi Arabia', 'Japan', 'Italy', 'Spain', 'Fair Trade Commission', 'Dentsu', 'Hakuhodo DY Holdings Inc', 'Tokyu Agency Inc', 'Fuji Creative Corporation', 'Cerespo Co', 'Same Two Inc', 'Tokyo Olympics organising committee', 'ADK Holdings', 'Aoki Holdings', 'Kadokawa', 'Singapore and Cambodia', 'South Korea', 'Germany', 'United States', 'Canada', 'Mexico', 'South Korea', 'Germany', 'United States', 'Canada', 'Mexico', 'Premier League', 'Australia', 'Spain', 'Napoli', 'Dubai', 'US', 'Spain', 'Pretoria', 'Champions League', 'Milan', 'Tottenham', 'Serbia', 'Russia', 'Belarus', 'Ukraine', 'United States', 'France', 'Torino', 'France', 'France', 'France', 'Manchester United', 'Newcastle', 'and West Ham United', 'Manchester United', 'Newcastle', 'and West Ham United', 'Italy', 'London', 'Italy', 'Las Vegas', 'Spanish', 'Argentina']

# %%
# GPEs extracted using NLTK
nltk_gpe = eval_cna2['nltk_gpe'].values.tolist()

new_nltk_gpe = []
for x in nltk_gpe:
    if len(x)>1:
        txt = x.split(",")
        for n in txt:
            if n != '':
                new_nltk_gpe.append(n.lstrip())

print(new_nltk_gpe)
# Out:
# ['Australia', 'India', 'Indore', 'Cummins', 'Indian', 'New Delhi', 'Antalyaspor', 'Turkey', 'Ghana', 'West', 'Zimbabwe', 'Australia', 'South Africa', 'Brathwaite', 'Discipline', 'West', 'Zimbabwe', 'Australia', 'South Africa', 'Brathwaite', 'Discipline', 'Britain', 'Bakuriani', 'Georgia', 'Briton', 'Brooks', 'New Zealand', 'Japan', 'Canada', 'Bontis', 'Canadian', 'MUNICH', 'Germans', 'Paris', 'Bayern', 'Europe', 'French', 'Messi', 'Vitinha', 'Dutch', 'Newcastle', 'Saudi', 'United', 'English', 'Tottenham', 'London', 'Italian', 'Italy', 'Australian', 'Djokovic', 'Netherlands', 'Doha', 'Italian', 'American', 'Botic', 'Dubai', 'Djokovic', 'Dubai', 'Djokovic', 'BRISTOL', 'England', 'Foden', 'Bristol', 'Fulham', 'Brighton', 'Bristol City', 'Haaland', 'European', 'Palhinha', 'Israeli Solomon', 'Bahrain', 'Abu Dhabi', 'U.S.', 'China', 'April', 'France', 'Qatar', 'Azerbaijan', 'Belgium', 'Brazil', 'Calendar', 'Sakhir', 'Saudi Arabia', 'Jeddah', 'Australia', 'Spain', 'Barcelona', 'Canada', 'Austria', 'Britain', 'Hungary', 'Netherlands', 'Italy', 'Singapore', 'Japan', 'Suzuka', 'United States', 'Austin', 'Mexico', 'PARIS', 'French', 'Graet', 'France', 'Diacre', 'Fellow', 'Norway', 'England', 'Germany', 'Women', 'Australia', 'New Zealand', 'United', 'Dutch', 'Portuguese', 'Barcelona', 'August', 'Newcastle', 'Weghorst', 'Bristol City', 'English', 'Bournemouth', 'Bristol City', 'English', 'Bournemouth', 'Lydia', 'Singapore', 'New', 'Saudi Arabia', 'Australian', 'August', 'Thailand', 'South', 'Asia', 'Doha', 'Asian', 'Japan', 'Saudi Arabia', 'Urawa', 'Nigerian', 'Brazilian', 'Marega', 'Porto', 'Zakaria', 'BOLOGNA', 'Italy', 'Bologna', 'Inzaghi', 'Porto', 'Soriano', 'Romelu', 'Spain', 'TOKYO', 'Japanese', 'Japan', 'Hakuhodo', 'SINGAPORE', 'Cambodia', 'South Korea', 'Germany', 'United States', 'Canada', 'Mexico', 'Korean', 'Asian', 'Colombia', 'German', 'South Korea', 'Germany', 'United States', 'Canada', 'Mexico', 'Korean', 'Asian', 'Colombia', 'German', 'Liverpool', 'Colombian', 'Uruguayan', 'LOS', 'Indian', 'Australian', 'July', 'August', 'U.S.', 'Japan', 'Australian Open', 'Spain', 'Almeria', 'Barca', 'Malian', 'La', 'Europe', 'Barcelona', 'Sampdoria', 'Lazio', 'Cremonese', 'Runaway', 'Midfielder', 'Dubai', 'Murray', 'U.S.', 'Texas', 'Indian', 'Australian', 'Nadal', 'Australian Open', 'South', 'West', 'Australia', 'England', 'Pretoria', 'South Africa', 'London', 'Europe', 'European', 'Milan', 'Serie', 'Serbian', 'United States', 'Russia', 'Belarus', 'Moscow', 'Ukraine', 'Dubai', 'Grand Slams', 'Djokovic', 'Facebook', 'Helsinki', 'Melbourne', 'American', 'United States', 'Juventus', 'Torino', 'France', 'Qatar', 'Chiesa', 'Italian', 'PARIS', 'Mbappe', 'Argentine', 'France', 'Argentina', 'Marseille', 'Nice', 'French', 'Messi', 'PARIS', 'Mbappe', 'Argentine', 'France', 'Argentina', 'Marseille', 'Nice', 'French', 'Messi', 'MUNICH', 'Germany', 'Bayern', 'Europe', 'France', 'European', 'Galtier', 'United', 'Rashford', 'United', 'Rashford', 'DUBLIN', 'Ireland', 'Italy', 'Irish', 'Furlong', 'British', 'Italian', 'Scotland', 'England', 'British', 'Chelsea', 'Spurs', 'Tottenham', 'European', 'U.S.', 'Bahrain', 'Dutch', 'Sauber', 'Australian', 'Alpine', 'United States', 'German', 'Hamilton', 'Alonso', 'America', 'Netflix', 'Acapulco', 'U.S.', 'Norrie', 'Mexico', 'Briton', 'Indian', 'Argentina', 'Qatar', 'Paris', 'Canada', 'Mexico', 'United States', 'Scaloni', 'Mallorca', 'Russia', 'Italy']

# %%
#nltk precision, recall, f1 score of GPE
correct = 0

for x in new_nltk_gpe:
    if x in new_true_gpe:
        correct+=1

nltk_gpe_recall = correct/len(new_true_gpe)
nltk_gpe_precision = correct/len(new_nltk_gpe)
nltk_gpe_f1_score = 2*((nltk_gpe_precision * nltk_gpe_recall)/ (nltk_gpe_precision + nltk_gpe_recall))
    
print("Recall = ", nltk_gpe_recall)
print()
print("Precision = ", nltk_gpe_precision)
print()
print("f1 score = ", nltk_gpe_f1_score)
# Out:
# Recall =  0.8174603174603174
#
# Precision =  0.3344155844155844
#
# f1 score =  0.4746543778801842

# %% [markdown]
# Person

# %%
# Person from gold truth
true_per = eval_cna2["person"].values.tolist()

new_true_per = []
for x in true_per:
    if len(x)>1:
        txt = x.split(",")
        for n in txt:
            if n != '':
                new_true_per.append(n.lstrip())

print(new_true_per)
# Out:
# ['Mitchell Starc', 'Pat Cummins', 'David Warner', 'Cameron Green', 'Steve Smith', 'Srikar Bharat', 'Christian Atsu', 'Kraigg Brathwaite', 'Kraigg Brathwaite', 'Mia Brookes', 'Zoi Sadowski-Synnott', 'Onitsuka Miyabi', 'Nick Bontis', 'Eric-Maxim Choupo-Moting', 'Serge Gnabry', 'Leon Goretzka', 'Lionel Messi', 'Kylian Mbappe', 'Julian Nagelsmann', 'Neymar', 'Gianluigi Donnarumma', 'Jamal Musiala', 'Marquinhos', 'Vitinha', 'Matthijs de Ligt', 'Sergio Ramos', 'Christophe Galtier', 'Casemiro', 'Sven Botman', 'Eddie Howe', 'Erik ten Hag', 'Jose Mourinho', 'Bruno Fernandes', 'Luke Shaw', 'Loris Karius', 'Marcus Rashford.', 'Antonio Conte', 'Novak Djokovic', 'Tomas Machac', 'Steffi Graf', 'Tallon Griekspoor', 'Daniil Medvedev', 'Matteo Arnaldi', 'Felix Auger-Aliassime', 'Maxime Cressy', 'Karen Khachanov', 'Botic van de Zandschulp', 'Novak Djokovic', 'Rafa Nadal', 'Steffi Graf', 'Tomas Machac', 'Novak Djokovic', 'Rafa Nadal', 'Steffi Graf', 'Tomas Machac', 'Phil Foden', 'Pep Guardiola', 'Kevin De Bruyne', 'Tyrhys Dolan', 'Sammie Szmodics', 'Kelechi Iheanacho', 'Joao Palhinha', 'Manor Solomon', 'Evan Ferguson', 'Kalvin Phillips', 'Riyad Mahrez', 'Mark Sykes', 'Rico Lewis', 'Alex Scott', 'Stefan Ortega', 'Brendan Rodgers', 'Marco Silva', 'None', 'Noel Le Graet', 'Zinedine Zidane', 'Didier Deschamps', 'Corinne Diacre', 'Wendie Renard', 'Marie-Antoinette Katoto', 'Kadidiatou Diani', 'Amandine Henry', 'Eugenie Le Sommer', 'Gaetane Thiney', 'Sarah Bouhaddi', 'Amelie Oudea-Castera', 'Cristiano Ronaldo', 'Erik ten Hag', 'Marcus Rashford', 'Casemiro', 'Lisandro Martinez', 'Raphael Varane', 'Antony', 'Wout Weghorst.', 'Pep Guardiola', 'Nigel Pearson', 'Kevin De Bruyne', 'Pep Guardiola', 'Nigel Pearson', 'Kevin De Bruyne', 'Lydia Ko', 'Nelly Korda', 'Minjee Lee', 'Ko Jin-young', 'Park In-bee', 'Odion Ighalo', 'Moussa Marega', 'Salem Al Dawsari', 'Mohammed Kanno', 'Salah Zakaria', 'Michael Oliveira', 'Jang Hyun-soo', 'Abdullah Al Mauoif', 'Maciej Skorza', 'Abdullah Al Hamdan', 'Riccardo Orsolini', 'Musa Barrow', 'Roberto Soriano', 'Andre Onana', 'Andrea Cambiaso', 'Federico Dimarco', 'Milan Skriniar', 'Joaquin Correa', 'Nicolo Barella', 'Lautaro Martinez', 'Alessandro Bastoni', 'Henrikh Mkhitaryan', 'Dominguez', 'Jerdy Schouten', 'Romelu Lukaku', 'Edin Dzeko', 'Simone Inzaghi', 'Joseph Burrows', 'Corey Rutgers', 'Goh Okumura', 'Haruyuki Takahashi', 'Joseph Schooling', 'Juergen Klinsmann', 'Paulo Bento', 'Gus Hiddink', 'Juergen Klinsmann', 'Paulo Bento', 'Gus Hiddink', 'Juergen Klopp', 'Thiago Alcantara', 'Joe Gomez', 'Luis Diaz', 'Darwin Nunez', 'Diogo Jota', 'Nick Kyrgios', 'El Bilal Toure', 'Luis Suarez', 'Leo Baptistao', 'Marc-Andre ter Stegen', 'Rodrigo Ely', 'Xavi Hernandez', 'Luis Alberto', 'Ciro Immobile', 'Maurizio Sarri', 'Andy Murray', 'Rafa Nadal', 'Taylor Fritz', 'Mackenzie McDonald.', 'Temba Bavuma', 'Aiden Markram', 'Ryan Rickelton', 'Tony de Zorzi', 'Heinrich Klaasen', 'Shukri Conrad.', 'Stefano Pioli', 'Novak Djokovic', 'Tomas Machac', 'Bob Richards', 'Paul Pogba', 'Massimiliano Allegri', 'Federico Chiesa', 'Ivan Juric', 'Leonardo Bonucci', 'Lionel Messi', 'Kylian Mbappe', 'Neymar', 'Edinson Cavani', 'Sergio Ramos', 'Igor Tudor', 'Terem Moffi', 'Khephren Thuram', 'Presnel Kimpembe', 'Matteo Guendouzi', 'Pau Lopez', 'Marquinhos', 'Gianluigi Donnarumma', 'Nuno Tavares', 'Lionel Messi', 'Kylian Mbappe', 'Neymar', 'Edinson Cavani', 'Sergio Ramos', 'Igor Tudor', 'Terem Moffi', 'Khephren Thuram', 'Presnel Kimpembe', 'Matteo Guendouzi', 'Pau Lopez', 'Marquinhos', 'Gianluigi Donnarumma', 'Nuno Tavares', 'Christophe Galtier', 'Kylian Mbappe', 'Lionel Messi', 'Eric-Maxim Choupo-Moting', 'Serge Gnabry', 'Marcus Rashford', 'Casemiro', 'Sven Botman', 'Marcus Rashford', 'Casemiro', 'Sven Botman', 'Finlay Bealham', 'Tadhg Furlong', 'Johnny Sexton', 'Garry Ringrose', 'Robbie Henshaw', 'Jamison Gibson Park', 'Oliver Skipp', 'Harry Kane', 'Enzo Fernandez', 'Kepa Arrizabalaga', 'Son Heung-min', 'Eric Dier', 'Graham Potter', 'Antonio Conte', 'Stefano P ...

# %%
# Persons extracted using NLTK
nltk_per = eval_cna2['nltk_person'].values.tolist()

new_nltk_per = []
for x in nltk_per:
    if len(x)>1:
        txt = x.split(",")
        for n in txt:
            if n != '':
                new_nltk_per.append(n.lstrip())

print(new_nltk_per)
# Out:
# ['Starc', 'Pat Cummins', 'David Warner', 'Cameron Green', 'Steve Smith', 'Srikar Bharat', 'Bharat', 'Besiktas', 'Christian Atsu', 'Kraigg Brathwaite', 'Brathwaite', 'Kraigg Brathwaite', 'Brathwaite', 'Zoi', 'Brooks', 'Brookes', 'Soccer', 'Nick Bontis', 'Canada Soccer', 'Bontis', 'Bayern Munich', 'Serge Gnabry', 'Paris St Germain', 'Leon Goretzka', 'Gnabry', 'Lionel Messi', 'Kylian Mbappe', 'Julian Nagelsmann', 'Neymar', 'Mbappe', 'Jamal Musiala', 'Gianluigi Donnarumma', 'Marquinhos', 'Yann Sommer', 'Matthijs', 'Sergio Ramos', 'Christophe Galtier', 'United', 'Casemiro', 'Sven Botman', 'Eddie Howe', 'Erik', 'Hag', 'Jose Mourinho', 'Bruno Fernandes', 'Brazilian Casemiro', 'Luke Shaw', 'Loris Karius', 'Marcus Rashford', 'Karius', 'Dutchman Ten Hag', 'Antonio Conte', 'Conte', 'Juventus', 'Chelsea', 'Tottenham', 'Wolverhampton Wanderers', 'Milan', 'Novak', 'Djokovic', 'Czech', 'Tomas Machac', 'Dubai Tennis', 'Steffi Graf', 'Machac', 'Tomas', 'Tallon Griekspoor', 'Rotterdam', 'Daniil Medvedev', 'Matteo Arnaldi', 'Felix', 'Karen Khachanov', 'Novak', 'Djokovic', 'Rafa Nadal', 'Serb', 'Steffi Graf', 'Graf', 'Czech Tomas Machac', 'Novak', 'Djokovic', 'Rafa Nadal', 'Serb', 'Steffi Graf', 'Graf', 'Czech Tomas Machac', 'Phil Foden', 'Manchester City', 'Bristol City', 'Leicester City', 'Pep Guardiola', 'Kevin De Bruyne', 'Tyrhys Dolan', 'Joao Palhinha', 'Manor Solomon', 'Leeds United', 'Hove Albion', 'Evan Ferguson', 'Stoke City', 'Guardiola', 'Kalvin Phillips', 'City', 'Foden', 'Riyad Mahrez', 'Mark Sykes', 'Rico Lewis', 'Alex Scott', 'Stefan Ortega', 'De Bruyne', 'Nathan Ake', 'Zak Vyner', 'Brendan Rodgers', 'Marco Silva', 'Leeds', 'Silva', 'League Cup', 'Manchester United', 'Las', 'Qatar', 'Austin', 'Miami May', 'Emilia Romagna', 'Monaco', 'Qatar Oct', 'Las Vegas', 'Abu Dhabi', 'Noel', 'Le Graet', 'Amelie Oudea-Castera', 'Le', 'Zinedine Zidane', 'Didier Deschamps', 'Corinne Diacre', 'Wendie Renard', 'Women', 'Renard', 'Denmark', 'Uruguay', 'Diacre', 'Clermont', 'Gaetane Thiney', 'Sarah Bouhaddi', 'Henry', 'Eugenie Le Sommer', 'Erik', 'Marcus Rashford', 'Casemiro', 'Lisandro Martinez', 'Raphael Varane', 'Antony', 'Ten Hag', 'Pep Guardiola', 'Bristol City', 'Nigel Pearson', 'Manchester City', 'Guardiola', 'Leicester', 'Watford', 'Kevin De Bruyne', 'John Stones', 'Aymeric Laporte', 'Pep Guardiola', 'Bristol City', 'Nigel Pearson', 'Manchester City', 'Guardiola', 'Leicester', 'Watford', 'Kevin De Bruyne', 'John Stones', 'Aymeric Laporte', 'Nelly Korda', 'Zealander Ko', 'Ko', 'Ko Jin-young', 'Park In-bee', 'Al Hilal', 'Qatar', 'Al Duhail', 'Urawa Red Diamonds', 'Odion', 'Ighalo', 'Moussa Marega', 'Salem Al Dawsari', 'Maciej Skorza', 'Mohammed Kanno', 'Salah Zakaria', 'Michael Oliveira', 'Jang Hyun-soo', 'Marega', 'Al Dawsari', 'Abdullah Al Mauoif', 'Al', 'Dawsari', 'Abdullah Al Hamdan', 'Al Ittihad', 'Milan', 'Serie', 'Riccardo Orsolini', 'Simone', 'Inzaghi', 'Napoli', 'Bologna', 'Stadio Renato', 'Musa Barrow', 'Roberto Soriano', 'Andre Onana', 'Andrea Cambiaso', 'Federico Dimarco', 'Milan Skriniar', 'Joaquin Correa', 'Nicolo Barella', 'Lautaro Martinez', 'Alessandro Bastoni', 'Henrikh Mkhitaryan', 'Dominguez', 'Edin Dzeko', 'Orsolini', 'Jerdy Schouten', 'Schouten', 'Man', 'Joseph Burrows', 'Crazy', 'Spain', 'Corey Rutgers', 'Sydney Thunder', 'Dentsu', 'Hakuhodo', 'Tokyu Agency', 'Fuji Creative Corporation', 'Cerespo', 'Tokyo Agency', 'Fuji Creative', 'Fuji Media Holdings', 'Gary Tan', 'Schooling', 'Joe', 'Tan', 'Juergen', 'Klinsmann', 'Paulo Bento', 'Brazil', 'Bayern Munich', 'Juergen', 'Klinsmann', 'Paulo Bento', 'Brazil', 'Bayern Munich', 'Liverpool', 'Wolverhampton Wanderers', 'Juergen Klopp', 'Tottenham Hotspur', 'Klopp', 'Manchester United', 'Anfield', 'Wolves', 'Thiago Alcantara', 'Joe Gomez', 'Luis Diaz', 'Darwin Nunez', 'Diogo Jota', 'Diogo', 'Nick Kyrgios', 'Miami', 'Barcelona', 'El Bilal Toure', 'Barca', 'Luis Suarez', 'Leo Baptistao', 'Stegen', 'Rodrigo', 'Xavi Hernandez', 'Xavi', 'Luis', 'Alberto', 'Lazio', 'Serie', 'Maurizio', 'S ...

# %%
#nltk precision, recall, f1 score for person
correct = 0

for x in new_nltk_per:
    if x in new_true_per:
        correct+=1

nltk_per_recall = correct/len(new_true_per)
nltk_per_precision = correct/len(new_nltk_per)
nltk_per_f1_score = 2*((nltk_per_precision * nltk_per_recall)/ (nltk_per_precision + nltk_per_recall))
    
print("Recall = ", nltk_per_recall)
print()
print("Precision = ", nltk_per_precision)
print()
print("f1 score = ", nltk_per_f1_score)
# Out:
# Recall =  0.7689393939393939
#
# Precision =  0.4134419551934827
#
# f1 score =  0.5377483443708608

# %% [markdown]
# Org

# %%
# Organisations from gold truth
true_org = eval_cna2["organisation"].values.tolist()

new_true_org = []
for x in true_org:
    if len(x)>1:
        txt = x.split(",")
        for n in txt:
            if n != '':
                new_true_org.append(n.lstrip())

print(new_true_org)
# Out:
# ['Australia cricket team', 'India cricket team', 'Besiktas', 'West Indies cricket team', 'South Africa cricket team', 'West Indies cricket team', 'South Africa cricket team', 'FIS (International Ski Federation)', 'Canada Soccer', "men's and women's national teams", "players' association", 'Bayern Munich', 'Paris St Germain', 'Manchester United', 'Newcastle United', 'VAR', 'Tottenham Hotspur', 'AC Milan', 'Juventus', 'Inter Milan', 'Chelsea', 'ATP Tour', 'Dubai Tennis Championships', 'ATP Tour', 'ATP Tour', 'Manchester City', 'Leicester City', 'Blackburn Rovers', 'Fulham', 'Leeds United', 'Brighton and Hove Albion', 'West Ham United', 'Formula One', 'French Football Federation (FFF)', 'Manchester United', 'Ajax Amsterdam', 'Barcelona', 'Brentford', 'Manchester City', 'American Glazer family.', 'Manchester City', 'Manchester City', "HSBC Women's World Championship", 'Asian Champions League', 'Al Hilal', 'Al Duhail', 'Urawa Red Diamonds', 'Manchester United', 'J.League', 'Porto', 'Inter Milan', 'Napoli', 'Empoli', 'AC Milan', 'AS Roma', 'Bologna', 'Champions League', 'VAR', 'DAZN', 'Sydney Thunder', 'Fair Trade Commission', 'Dentsu', 'Hakuhodo DY Holdings Inc', 'Tokyu Agency Inc', 'Fuji Creative Corporation', 'Cerespo Co', 'Same Two Inc', 'Tokyo Olympics organising committee', 'ADK Holdings', 'Aoki Holdings', 'Kadokawa', 'Southeast Asian Games', 'South Korea Football Association (KFA)', 'Bayern Munich', 'US national team', 'CONCACAF', 'South Korea Football Association (KFA)', 'Bayern Munich', 'US national team', 'CONCACAF', 'Liverpool FC', 'Wolverhampton Wanderers', 'Tottenham Hotspur', 'Manchester United', 'ATP', 'Barcelona', 'Real Madrid', 'Atletico Madrid', 'Europa League', 'Movistar Plus', 'Lazio', 'AS Roma', 'Inter Milan', 'AC Milan', 'Sampdoria', 'ATP', 'Dubai Tennis Championships', 'BNP Paribas Open.', 'South African cricket team.', 'AC Milan', 'Tottenham Hotspur', 'AS Roma', 'Chelsea', 'Bayern Munich', 'Benfica', 'Wimbledon Grand Slam', 'Populist Party', 'Juventus', 'Paris St Germain', 'Olympique de Marseille', 'RC Lens', 'Lille', 'Bayern Munich', 'Paris St Germain', 'Olympique de Marseille', 'RC Lens', 'Lille', 'Bayern Munich', 'Paris St Germain', 'Bayern Munich', 'Champions League', 'Manchester United', 'Newcastle United', 'Carabao Cup', 'Manchester United', 'Newcastle United', 'Carabao Cup', 'Irish Rugby Football Union (IRFU)', 'Tottenham Hotspur', 'Chelsea', 'AC Milan', 'Tottenham Hotspur', 'Champions League', 'FA Cup', 'Sheffield United', 'Wolverhampton Wanderers', 'Premier League.', 'Red Bull', 'Ferrari', 'Sauber/Alfa Romeo', 'McLaren', 'Williams', 'Haas', 'Alpine', 'AlphaTauri', 'Mercedes', 'Aston Martin', 'Andretti Cadillac', 'FIA.', 'ATP', "Argentina's FA", 'FIFA']

# %%
# Organisations extracted using NLTK
nltk_org = eval_cna2['nltk_org'].values.tolist()

new_nltk_org = []
for x in nltk_org:
    if len(x)>1:
        txt = x.split(",")
        for n in txt:
            if n != '':
                new_nltk_org.append(n.lstrip())

print(new_nltk_org)
# Out:
# ['Mitchell', 'Turkish Super Lig', 'Vodafone Park', 'Indies', 'Centurion Park', 'Indies', 'Centurion Park', 'Mia Brookes', 'FIS', 'Freestyle Ski', 'Beijing Olympics', 'Onitsuka Miyabi', 'SheBelievesCup', 'National Team', 'Champions League', 'PSG', 'VfB Stuttgart', 'Sommer', 'Spaniard', 'Newcastle United', 'League', 'Manchester United', 'Europa League', 'VAR', 'Newcastle', 'Tyneside', 'Champions League', 'Tottenham Hotspur', 'AC Milan', 'Inter Milan', 'Conte', 'Amazon', 'Europa Conference League', 'Sheffield United', 'ATP', 'Czech', 'Melbourne', 'ATP Tour', 'Adelaide', 'ATP Tour', 'Adelaide', 'Blackburn Rovers', 'Sammie Szmodics', 'Kelechi Iheanacho', 'City', 'Blackburn', 'Leicester', 'Vegas', 'Melbourne', 'Baku', 'Imola', 'Montreal', 'Spielberg', 'Zandvoort', 'Interlagos', 'FFF', 'Sports', 'Kadidiatou Diani', 'RMC Sport', 'Euro', 'European', 'League', 'Newcastle United', 'Wembley', 'Old Trafford', 'Ajax Amsterdam', 'American Glazer', 'Europa League', 'Brentford', 'Ashton Gate', 'League', 'City', 'Arsenal', 'Ashton Gate', 'League', 'City', 'Arsenal', 'Ko', 'HSBC Women', 'Sentosa Golf Club', 'American Korda', 'Minjee Lee', 'US', 'Koreans', 'LIVE', 'Manchester United', 'Mali', 'VAR', 'Bologna', 'AC Milan', 'AS Roma', 'VAR', 'Lukaku', 'DAZN', 'Inter', 'Nerazzurri', 'AC', 'Isle', 'Twenty20', 'Cricbuzz', 'T20s', 'Adelaide Strikers', 'Dentsu Group', 'Paralympics', 'Supreme Court', 'CEO', 'SEA Games', 'National Service', 'CNA', 'Korea Football Association', 'KFA', 'Gus Hiddink', 'US', 'CONCACAF', 'CONCACAF Coach', 'Korea Football Association', 'KFA', 'Gus Hiddink', 'US', 'CONCACAF', 'CONCACAF Coach', 'Anfield', 'Portugal', 'Crystal Palace', 'ANGELES', 'Wimbledon', 'ATP', 'LaLiga', 'Real', 'Atletico Madrid', 'Europa League', 'Movistar Plus', 'Real Madrid', 'AS Roma', 'Inter Milan', 'AC Milan', 'Stadio Olimpico', 'Genoa', 'Dubai Tennis', 'ATP', 'Qatar Open', 'Medvedev', 'Austin Open', 'US', 'Miami Open', 'Spaniard', 'Miami', 'BNP Paribas', 'Rod Laver Arena', 'American Mackenzie', 'Africa', 'Centurion Park', 'Champions League', 'AS Roma', 'US Open', 'Wimbledon', 'Populist Party', 'Leonardo', 'PSG', 'Montpellier', 'Argentine', 'Parc', 'PSG', 'Montpellier', 'Argentine', 'Parc', 'Champions League', 'PSG', 'Newcastle United', 'Old Trafford', 'Europa League', 'Newcastle United', 'Old Trafford', 'Europa League', 'Six Nations', 'IRFU', 'Lion Furlong', 'Blues', 'Newcastle United', 'AC Milan', 'Champions League', 'Tottenham Hotspur', 'Italians', 'San Siro', 'Sheffield United', 'Kulusevski', 'Bull', 'Max Verstappen', 'Mercedes', 'TRIPLE', 'MAX Verstappen', 'NEW', 'BOSSES Four', 'Ferrari', 'McLaren', 'Frenchman', 'FACES', 'Red', 'Williams', 'OLD', 'FACES Nico Hulkenberg', 'Haas', 'Fernando Alonso', 'Hamilton', 'One', 'TEAMS Andretti', 'MERCEDES', 'DEAL Hamilton', 'FIA', 'RICCIARDO', 'Red Bull', 'ATP', 'ATP Tour', 'Buenos Aires', 'Rio Open', 'FA', 'AFA', 'Lionel Scaloni', 'Senior Selection', 'FIFA', 'Newell', 'Old Boys', 'Lionel', 'Copa America']

# %%
#nltk precision, recall, f1 score of organisation entity
correct = 0

for x in new_nltk_org:
    if x in new_true_org:
        correct+=1

nltk_org_recall = correct/len(new_true_org)
nltk_org_precision = correct/len(new_nltk_org)
nltk_org_f1_score = 2*((nltk_org_precision * nltk_org_recall)/ (nltk_org_precision + nltk_org_recall))
    
print("Recall = ", nltk_org_recall)
print()
print("Precision = ", nltk_org_precision)
print()
print("f1 score = ", nltk_org_f1_score)
# Out:
# Recall =  0.3815789473684211
#
# Precision =  0.25892857142857145
#
# f1 score =  0.30851063829787234

# %% [markdown]
# Average recall, precision & f1 score

# %%
avg_recall = (nltk_org_recall + nltk_per_recall + nltk_gpe_recall + nltk_loc_recall)/4
avg_precision = (nltk_org_precision + nltk_per_precision + nltk_gpe_precision + nltk_loc_precision)/4
avg_f1_score = (nltk_org_f1_score + nltk_per_f1_score + nltk_gpe_f1_score + nltk_loc_f1_score)/4

print("Recall = ", avg_recall)
print()
print("Precision = ", avg_precision)
print()
print("f1 score = ", avg_f1_score)
# Out:
# Recall =  0.4951997928971613
#
# Precision =  0.2971510732139551
#
# f1 score =  0.33621636408932515

# %% [markdown]
# #### spacy

# %%
# locations extracted using spaCy
spacy_loc = eval_cna2['spacy_location'].values.tolist()

new_spacy_loc = []
for x in spacy_loc:
    if len(x)!=0:
        txt = x.split(",")
        for i in txt:
            new_spacy_loc.append(i.strip())

print(new_spacy_loc)
# Out:
# ['West Indies', 'Caribbean', 'West Indies', 'Caribbean', 'Europe', 'Erling Haaland', 'West Ham United', 'Asia', 'Al Thumama Stadium', 'The Isle of Man', "the Isle of Man's", 'the SEA Games', 'Indian Wells', 'Europe', 'Indian Wells', 'West Indies', 'the West Indies', 'Europe', 'Europe', 'West Ham United', 'West Ham United', 'Bealham', 'Strip']

# %%
#spacy precision, recall, f1 score of locations
correct = 0

for x in new_spacy_loc:
    if x in new_true_loc:
        correct+=1

spacy_loc_recall = correct/len(new_true_loc)
spacy_loc_precision = correct/len(new_spacy_loc)
spacy_loc_f1_score = 2*((spacy_loc_precision * spacy_loc_recall)/ (spacy_loc_precision + spacy_loc_recall))
    
print("Recall = ", spacy_loc_recall)
print()
print("Precision = ", spacy_loc_precision)
print()
print("f1 score = ", spacy_loc_f1_score)
# Out:
# Recall =  0.04487179487179487
#
# Precision =  0.30434782608695654
#
# f1 score =  0.0782122905027933

# %% [markdown]
# GPE

# %%
# GPE extracted using spaCy
spacy_gpe = eval_cna2['spacy_gpe'].values.tolist()

new_spacy_gpe = []
for x in spacy_gpe:
    if len(x)>1:
        txt = x.split(",")
        for i in txt:
            new_spacy_gpe.append(i.strip())

print(new_spacy_gpe)
# Out:
# ['Australia', 'India', 'New Delhi', 'Turkey', 'Syria', 'South Africa', 'Zimbabwe', 'Australia', 'Gqeberha', 'South Africa', 'Zimbabwe', 'Australia', 'Gqeberha', 'Britain', 'Bakuriani', 'Georgia', "New Zealand's", 'Japan', 'Canada', 'Paris', 'Neymar', 'Messi', 'LONDON', "Newcastle United's", 'Casemiro', 'Newcastle', 'Saudi Arabia', 'Europa League', 'LONDON', 'London', 'Tottenham', 'Italy', 'Amazon Prime', 'Sheffield United', 'Milan', 'Dubai', 'Netherlands', 'Doha', 'Melbourne', 'Dubai', 'Dubai', 'England', 'Manchester City', 'Bristol City', "Leicester City's", 'Leeds United', 'Stoke City', 'Bahrain', 'Abu Dhabi', 'Las Vegas', 'U.S.', 'China', 'France', 'Qatar', 'Azerbaijan', 'Austria', 'Belgium', 'Austin', 'Brazil', 'Jeddah', 'Melbourne', 'Baku', 'Imola', 'Barcelona', 'Silverstone', 'Suzuka', 'Interlagos', 'PARIS', 'France', 'Diacre', 'Katoto', 'Kadidiatou Diani', 'Norway', 'Denmark', 'Uruguay', 'England', 'Germany', 'Australia', 'New Zealand', 'LONDON', "Newcastle United's", 'Barcelona', 'Manchester City', 'Casemiro', 'Newcastle', 'Manchester City', 'Bristol City', 'Leicester', 'Manchester City', 'Bristol City', 'Leicester', 'Singapore', 'Saudi Arabia', 'Thailand', 'Qatar', 'Doha', 'Japan', 'Salem', 'Saudi Arabia', 'Urawa', 'Italy', 'Napoli', 'Romelu Lukaku', 'Onana', 'Spain', 'Thunder', 'Japan', 'Cambodia', 'South Korea', 'Germany', "South Korea's", 'Brazil', 'the United States', 'Canada', 'Mexico', 'US', 'Colombia', 'South Korea', 'Germany', "South Korea's", 'Brazil', 'the United States', 'Canada', 'Mexico', 'US', 'Colombia', 'Liverpool', 'Anfield', 'Portugal', 'LOS ANGELES', 'Miami', 'U.S.', 'Spain', 'Barcelona', 'Almeria', 'El Bilal', 'La Liga', 'Sampdoria', 'Dubai', 'Texas', 'Miami', 'US', 'South Africa', 'Australia', 'England', 'Highveld', 'Pretoria', 'LONDON', 'Milan', 'London', 'Pioli', 'Tottenham', 'the United States', 'Russia', 'Belarus', 'Moscow', 'Ukraine', 'Dubai', 'Helsinki', 'Melbourne', 'the United States', 'Torino', 'France', 'Qatar', 'Paris', 'Neymar', 'France', 'Messi', 'Argentina', 'Monaco', 'Lille', 'Achilles', 'Ligue', 'Champions League last-16', 'Paris', 'Neymar', 'France', 'Messi', 'Argentina', 'Monaco', 'Lille', 'Achilles', 'Ligue', 'Champions League last-16', 'MUNICH', 'Germany', 'Paris', 'France', 'Casemiro', 'Rashford', 'Casemiro', 'Rashford', 'Italy', 'Ireland', 'Scotland', 'England', 'LONDON', 'Spurs', 'LONDON', 'London', 'Tottenham', 'Milan', 'Sheffield United', 'Pioli', 'Fraser Forster', 'Las Vegas', 'U.S.', 'Bahrain', 'the United States', 'LAS VEGAS', 'America', 'Acapulco', 'U.S.', 'Mexico', 'Argentina', 'Qatar', 'Paris', 'Canada', 'Mexico', 'the United States', 'Russia', 'Scaloni', 'Italy', 'Tapia']

# %%
#spacy precision, recall, f1 score of gpe
correct = 0

for x in new_spacy_gpe:
    if x in new_true_gpe:
        correct+=1

spacy_gpe_recall = correct/len(new_true_gpe)
spacy_gpe_precision = correct/len(new_spacy_gpe)
spacy_gpe_f1_score = 2*((spacy_gpe_precision * spacy_gpe_recall)/ (spacy_gpe_precision + spacy_gpe_recall))
    
print("Recall = ", spacy_gpe_recall)
print()
print("Precision = ", spacy_gpe_precision)
print()
print("f1 score = ", spacy_gpe_f1_score)
# Out:
# Recall =  0.8174603174603174
#
# Precision =  0.45982142857142855
#
# f1 score =  0.5885714285714285

# %% [markdown]
# Person

# %%
# person extracted using spaCy
spacy_per = eval_cna2['spacy_person'].values.tolist()

new_spacy_per = []
for x in spacy_per:
    if len(x)>1:
        txt = x.split(",")
        for i in txt:
            new_spacy_per.append(i.strip())

print(new_spacy_per)
# Out:
# ['Mitchell Starc', 'Pat Cummins', 'David Warner', 'Starc', 'Cameron Green', 'Cummins', 'Steve Smith', 'Srikar Bharat', 'Ghana', 'Christian Atsu', 'Kraigg Brathwaite', 'Brathwaite', 'Kraigg Brathwaite', 'Brathwaite', 'Mia Brookes', 'Zoi Sadowski-Synnott', 'Brooks', 'Nick Bontis', 'Bayern Munich', 'Eric-Maxim Choupo-Moting', 'Serge Gnabry', "Leon Goretzka's", 'Gnabry', 'Messi', 'Kylian Mbappe', 'Julian Nagelsmann', "Jamal Musiala's", 'Gianluigi Donnarumma', 'Marquinhos', 'Yann Sommer', 'Vitinha', "Sergio Ramos's", 'Sommer', 'Eddie Howe', "Erik ten Hag's", 'Jose Mourinho', 'Bruno Fernandes', 'Brazilian Casemiro', 'Luke Shaw', 'Loris Karius', 'Marcus Rashford', "Antonio Conte's", 'Conte', 'Wolverhampton Wanderers', 'Novak Djokovic', 'Tomas Machac', 'Djokovic', 'Rotterdam', 'Daniil Medvedev', 'Felix Auger-Aliassime', 'Karen Khachanov', 'Botic van de Zandschulp', 'Novak Djokovic', 'Rafa Nadal', 'Tomas Machac', 'Novak Djokovic', 'Rafa Nadal', 'Tomas Machac', "Phil Foden's", 'Kevin De Bruyne', 'Blackburn Rovers', 'Tyrhys Dolan', 'Joao Palhinha', "Evan Ferguson's", 'Kalvin Phillips', "Riyad Mahrez's", 'Mark Sykes', 'Alex Scott', 'Stefan Ortega', 'De Bruyne', 'Nathan Ake', 'Zak Vyner', 'Guardiola', 'Blackburn', 'Brendan Rodgers', 'Marco Silva', 'Leeds', 'Silva', 'Manchester United', 'Spielberg', 'Amelie Oudea-Castera', 'Zinedine Zidane', 'Deschamps', 'Corinne Diacre', 'Wendie Renard', 'Renard', 'Gaetane Thiney', 'Sarah Bouhaddi', 'Wembley', 'Erik ten Hag', 'Glazer', 'Brentford', 'Marcus Rashford', 'Lisandro Martinez', 'Raphael Varane', 'Antony', 'Wout Weghorst', 'Pep Guardiola', 'Nigel Pearson', 'Bournemouth 4-1', 'Guardiola', 'Kevin De Bruyne', 'John Stones', 'Aymeric Laporte', 'Pep Guardiola', 'Nigel Pearson', 'Bournemouth 4-1', 'Guardiola', 'Kevin De Bruyne', 'John Stones', 'Aymeric Laporte', 'Lydia Ko', 'Nelly Korda', 'Zealander Ko', 'Korda', 'Ko', 'Lee', 'Ko Jin-young', 'Moussa Marega', 'Al Dawsari', 'Al Hilal', "Maciej Skorza's", "Mohammed Kanno's", 'Salah Zakaria', 'Michael Oliveira', 'Jang Hyun-soo', 'Marega', "Al Dawsari's", 'Mali', "Abdullah Al Mauoif's", 'Porto', 'Al Duhail', "Abdullah Al Hamdan's", 'Bologna', "Riccardo Orsolini's", 'Roberto Soriano', 'Andre Onana', "Andrea Cambiaso's", 'Federico Dimarco', 'Joaquin Correa', 'Nicolo Barella', 'Porto', 'Lautaro Martinez', 'Henrikh Mkhitaryan', 'Edin Dzeko', "Jerdy Schouten's", 'Nerazzurri', 'Twenty20', 'Joseph Burrows', 'Corey Rutgers', 'Sydney Thunder', 'Cerespo', 'Joseph Schooling', 'Gary Tan', 'Schooling', 'Joe', 'Tan', 'Juergen Klinsmann', 'Klinsmann', 'Paulo Bento', 'Gus Hiddink', 'Bayern Munich', 'Juergen Klinsmann', 'Klinsmann', 'Paulo Bento', 'Gus Hiddink', 'Bayern Munich', 'Wolverhampton Wanderers', 'Juergen Klopp', 'Klopp', 'Joe Gomez', 'Luis Diaz', 'Darwin Nunez', 'Diogo Jota', 'Nick Kyrgios', 'Barca', 'Luis Suarez', "Leo Baptistao's", 'Rodrigo Ely', 'Xavi Hernandez', "Luis Alberto's", 'Lazio', 'Cremonese', "Maurizio Sarri's", 'Luis Alberto', 'Andy Murray', 'Daniil Medvedev', 'Andy', 'Murray', 'Medvedev', 'Briton Emma Raducanu', 'Rafa Nadal', 'Nadal', 'Taylor Fritz', 'Tommy Haas', 'Rod Laver Arena', 'Temba Bavuma', 'Ryan Rickelton', 'Tony de Zorzi', 'Heinrich Klaasen', 'Shukri Conrad', 'Stefano Pioli', 'Bayern Munich', 'Benfica', 'Novak Djokovic', 'Tomas Machac', 'Carlos Alcaraz', 'Bob Richards', 'Brandon', 'Paul Pogba', 'Massimiliano Allegri', 'Federico Chiesa', 'Chiesa', 'Juve', 'Messi', 'Kylian Mbappe', 'Olympique de Marseille', 'Edinson Cavani', 'Sergio Ramos', 'Igor Tudor', 'Terem Moffi', 'Khephren Thuram', 'RC Lens', 'Presnel Kimpembe', 'Matteo Guendouzi', 'Mbappe', 'Pau Lopez', 'Bayern Munich', 'Messi', 'Kylian Mbappe', 'Olympique de Marseille', 'Edinson Cavani', 'Sergio Ramos', 'Igor Tudor', 'Terem Moffi', 'Khephren Thuram', 'RC Lens', 'Presnel Kimpembe', 'Matteo Guendouzi', 'Mbappe', 'Pau Lopez', 'Bayern Munich', 'Bayern Munich', 'Kylian Mbappe', 'Messi', 'Eric-Maxim Choupo-Moting', 'Serge Gnabry', 'Galtier', 'Newcastle United', 'Marcus Rashford', 'Trafford' ...

# %%
#spacy precision, recall, f1 score for person
correct = 0

for x in new_spacy_per:
    if x in new_true_per:
        correct+=1

spacy_per_recall = correct/len(new_true_per)
spacy_per_precision = correct/len(new_spacy_per)
spacy_per_f1_score = 2*((spacy_per_precision * spacy_per_recall)/ (spacy_per_precision + spacy_per_recall))
    
print("Recall = ", spacy_per_recall)
print()
print("Precision = ", spacy_per_precision)
print()
print("f1 score = ", spacy_per_f1_score)
# Out:
# Recall =  0.6477272727272727
#
# Precision =  0.5377358490566038
#
# f1 score =  0.5876288659793815

# %% [markdown]
# Organisation

# %%
# Organisations extracted using spaCy
spacy_org = eval_cna2['spacy_org'].values.tolist()

new_spacy_org = []
for x in spacy_org:
    if len(x)>1:
        txt = x.split(",")
        for i in txt:
            new_spacy_org.append(i.strip())

print(new_spacy_org)
# Out:
# ['Besiktas', 'The Turkish Super Lig', 'FIS', 'Briton', 'Brooks', 'Sadowski-Synnott', 'Onitsuka Miyabi', "Women's National Team", 'Choupo-Moting', 'Mbappe', 'Matthijs de Ligt', 'Bayern', 'Manchester United', 'Sven Botman', 'United', 'Botman', 'Wembley', 'Bruno Fernandes', 'Champions League', 'AC Milan', 'Juventus', 'Inter Milan', 'Chelsea', 'the Premier League', 'Tottenham', 'the Europa Conference League', "Steffi Graf's", 'Machac', 'American Maxime Cressy', 'the ATP Tour', 'Adelaide', 'the ATP Tour', 'Adelaide', 'BRISTOL', "Pep Guardiola's", 'Sammie Szmodics', 'Kelechi Iheanacho', 'Fulham', "Brighton and Hove Albion's", 'City', 'Bristol', 'Championship', 'Cottagers', 'the Premier League', 'League Cup', 'Noel Le Graet', 'FFF', 'the Sports ministry', 'Le Graet', "Women's World Cup", 'RMC Sport', 'Renard', 'Clermont', 'the European Championship', "The Women's World Cup", "Manchester United's", 'Ajax Amsterdam', 'Old Trafford', 'Cristiano Ronaldo', 'the Europa League', 'the Premier League', 'United', 'Ten Hag', 'Premier League', 'Championship', 'Guardiola', 'Bournemouth', 'Premier League', 'Championship', 'Guardiola', 'Bournemouth', "HSBC Women's World Championship", 'Sentosa Golf Club', 'Park In-bee', 'the HSBC Women’s World Championship 2023', 'Al Duhail', 'the Asian Champions League', 'Urawa Red Diamonds', 'Ighalo put Al Hilal', 'Manchester United', 'Al Ittihad', 'BOLOGNA', 'Inter Milan', 'Serie A', 'Inter', "Simone Inzaghi's", 'AC Milan', 'AS Roma', 'Milan Skriniar', 'Champions League', 'Alessandro Bastoni', 'Dominguez', 'DAZN', 'Cricbuzz', 'Adelaide Strikers', 'the Big Bash League', 'Dentsu Group', 'Dentsu', 'Supreme Court', 'Hakuhodo DY Holdings', 'Tokyu Agency', 'Fuji Creative Corporation', 'Hakuhodo', 'Tokyo Agency', 'Fuji Creative', 'Fuji Media Holdings', 'Cerespo', 'National Service', 'Navy', 'CNA', 'SEA Games', 'The Korea Football Association', 'KFA', 'Klinsmann', 'The Korea Football Association', 'KFA', 'Klinsmann', 'Liverpool', 'Manchester United', 'Thiago Alcantara', 'Crystal Palace', 'Grand Slam', 'LaLiga', 'Real Madrid', 'Atletico Madrid', 'the Europa League', 'Barca', 'Malian', 'Marc-Andre', 'Serie A', 'Inter Milan', 'AC Milan', 'Genoa', 'Grand Slam', 'Grand Slam', 'Indian Wells', 'Spaniard', 'AC Milan', 'the Champions League', 'Serie A', 'Champions League', 'Chelsea', 'Grand Slam', "Steffi Graf's", 'Stefanos Tsitsipas', 'Wheaties', 'the Populist Party', 'Juventus', 'Serie A', 'Monza', 'Allegri', 'Mbappe', 'PSG', 'Marseille', 'Monaco', 'Nice', 'Montpellier', 'Marquinhos', "Nuno Tavares's", 'Nantes', 'the Parc des Princes', 'Mbappe', 'PSG', 'Marseille', 'Monaco', 'Nice', 'Montpellier', 'Marquinhos', "Nuno Tavares's", 'Nantes', 'the Parc des Princes', 'the Champions League', 'Bayern', 'Mbappe', "Manchester United's", 'Sven Botman', 'United', 'the Europa League', "Manchester United's", 'Sven Botman', 'United', 'the Europa League', 'Six Nations', 'the Irish Rugby Football Union', 'British & Irish Lion Furlong', 'Skipp', 'Kepa Arrizabalaga', 'Chelsea', 'AC Milan', 'Tottenham', 'GEAR', 'Emerson', "Red Bull's", 'Formula One', 'Ferrari', 'Mercedes', 'Sauber/Alfa Romeo', 'McLaren', 'Williams', 'FERRARI', 'Vasseur', 'Alpine', 'Nyck de Vries', 'Red Bull-owned', 'AlphaTauri', 'Logan Sargeant', 'Haas', 'TEAMS', 'Andretti Cadillac', 'Red Bull', 'FIA', 'Alcaraz', 'the ATP Tour', 'Briton', 'Instagram', 'FA', 'AFA', 'Lionel Scaloni', 'FIFA', 'Mallorca', 'the Copa America']

# %%
#spacy precision, recall, f1 score of organisations
correct = 0

for x in new_spacy_org:
    if x in new_true_org:
        correct+=1

spacy_org_recall = correct/len(new_true_org)
spacy_org_precision = correct/len(new_spacy_org)
spacy_org_f1_score = 2*((spacy_org_precision * spacy_org_recall)/ (spacy_org_precision + spacy_org_recall))
    
print("Recall = ", spacy_org_recall)
print()
print("Precision = ", spacy_org_precision)
print()
print("f1 score = ", spacy_org_f1_score)
# Out:
# Recall =  0.28289473684210525
#
# Precision =  0.19457013574660634
#
# f1 score =  0.23056300268096513

# %% [markdown]
# Average precision, recall, f1-score

# %%
avg_recall = (spacy_org_recall + spacy_per_recall + spacy_gpe_recall + spacy_loc_recall)/4
avg_precision = (spacy_org_precision + spacy_per_precision + spacy_gpe_precision + spacy_loc_precision)/4
avg_f1_score = (spacy_org_f1_score + spacy_per_f1_score + spacy_gpe_f1_score + spacy_loc_f1_score)/4

print("Recall = ", avg_recall)
print()
print("Precision = ", avg_precision)
print()
print("f1 score = ", avg_f1_score)
# Out:
# Recall =  0.4482385304753726
#
# Precision =  0.3741188098653988
#
# f1 score =  0.3712438969336421
