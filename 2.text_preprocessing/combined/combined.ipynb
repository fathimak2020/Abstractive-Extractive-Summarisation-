# %%
import pandas as pd

cnn = pd.read_csv("../cnn/cnn_FINAL.csv")
cna = pd.read_csv("../cna/cna_FINAL.csv")

combined_df = pd.concat([cnn, cna], axis=0)

combined_df
# Out:
#      Unnamed: 0.1  Unnamed: 0  \
# 0               0           0
# 1               1           1
# 2               2           2
# 3               3           3
# 4               4           4
# ..            ...         ...
# 134           134         134
# 135           135         135
# 136           136         136
# 137           137         137
# 138           138         138
#
#                                                    url  \
# 0    https://edition.cnn.com/2023/02/28/sport/los-a...
# 1    https://edition.cnn.com/2023/02/16/sport/lesle...
# 2    https://edition.cnn.com/2023/02/27/sport/damia...
# 3    https://edition.cnn.com/2023/02/27/football/su...
# 4    https://edition.cnn.com/2023/02/22/football/pa...
# ..                                                 ...
# 134  https://www.channelnewsasia.com/sport/fa-cup-q...
# 135  https://www.channelnewsasia.com/sport/man-unit...
# 136  https://www.channelnewsasia.com/sport/formula-...
# ...

# %%
combined_df.to_csv('combined_file.csv', index=False)
